# %% [markdown]
# #### <div style= "font-family: Cambria; font-weight:bold; letter-spacing: 0px; color:black; font-size:150%; text-align:left;padding:3.0px; background: #cceeff; border-bottom: 8px solid #004466" > TABLE OF CONTENTS<br><div>
# * [IMPORTS](#1)
# * [INTRODUCTION](#2)
#     * [CONFIGURATION](#2.1)
#     * [CONFIGURATION PARAMETERS](#2.2)
#     * [DATASET COLUMNS](#2.3)
# * [PREPROCESSING](#3)
# * [ADVERSARIAL CV](#4)
# * [EDA AND VISUALS](#5)
# * [DATA TRANSFORMS](#6)
# * [MODEL TRAINING](#7)
# * [ENSEMBLE AND SUBMISSION](#8)
# * [PLANNED WAY FORWARD](#9)

# %% [markdown]
# <a id="1"></a>
# # <div style= "font-family: Cambria; font-weight:bold; letter-spacing: 0px; color:black; font-size:120%; text-align:left;padding:3.0px; background: #cceeff; border-bottom: 8px solid #004466" > IMPORTS<br> <div>

# %%
# %%time 

# Installing select libraries:-
from gc import collect;
from warnings import filterwarnings;
filterwarnings('ignore');
from IPython.display import clear_output;

# !pip install -q category_encoders;
# !pip install -q /kaggle/input/lightgbm410/lightgbm-4.1.0-py3-none-manylinux_2_28_x86_64.whl;
# !pip install -q /kaggle/input/xgboost-2-0-0-whl/xgboost-2.0.1-py3-none-manylinux2014_x86_64.whl;
# !pip install -q /kaggle/input/sklegowheelfile/autograd-1.6.2-py3-none-any.whl;
# !pip install -q /kaggle/input/sklegowheelfile/scikit_lego-0.6.16-py2.py3-none-any.whl;

clear_output();

import xgboost as xgb, lightgbm as lgb, sklego;
print(f"---> Current XGBoost = {xgb.__version__} | LightGBM = {lgb.__version__} | SKLego = {sklego.__version__}");
print();
collect();
# Out:
# ---> Current XGBoost = 2.0.1 | LightGBM = 4.1.0 | SKLego = 0.6.16
#
# CPU times: user 5.24 s, sys: 1.12 s, total: 6.36 s
# Wall time: 2min 59s

# %%
# %%time

# General library imports:-
from copy import deepcopy;
import pandas as pd;
import numpy as np;
import re;
from scipy.stats import mode, kstest, normaltest, shapiro, anderson, jarque_bera;
from collections import Counter;
from itertools import product;
from colorama import Fore, Style, init;
from warnings import filterwarnings;
filterwarnings('ignore');
import joblib;
import os;

from tqdm.notebook import tqdm;
import seaborn as sns;
import matplotlib.pyplot as plt;
from matplotlib.colors import ListedColormap as LCM;
# %matplotlib inline

from pprint import pprint;

print();
collect();
clear_output();
# Out:
# CPU times: user 317 ms, sys: 29.9 ms, total: 347 ms
# Wall time: 435 ms

# %%
# %%time 

# Importing model and pipeline specifics:-
from category_encoders import OrdinalEncoder, OneHotEncoder;

# Pipeline specifics:-
from sklearn.preprocessing import (RobustScaler, 
                                   MinMaxScaler, 
                                   StandardScaler, 
                                   FunctionTransformer as FT,
                                   PowerTransformer,
                                  );
from sklearn.impute import SimpleImputer as SI;
from sklearn.model_selection import (RepeatedStratifiedKFold as RSKF, 
                                     StratifiedKFold as SKF,
                                     KFold, 
                                     RepeatedKFold as RKF, 
                                     cross_val_score, cross_val_predict
                                    );
from sklearn.inspection import permutation_importance;
from sklearn.feature_selection import mutual_info_classif, RFE;
from sklearn.pipeline import Pipeline, make_pipeline;
from sklearn.base import BaseEstimator, TransformerMixin;
from sklearn.compose import ColumnTransformer;

# ML Model training:-
from sklearn.metrics import median_absolute_error as medae,  make_scorer;
from xgboost import DMatrix, XGBRegressor;
from lightgbm import LGBMRegressor, log_evaluation, early_stopping, LGBMClassifier;
from catboost import CatBoostRegressor, Pool;
from sklearn.ensemble import (RandomForestRegressor as RFR, 
                              ExtraTreesRegressor as ETR,
                              AdaBoostRegressor as ABR,
                              BaggingRegressor as BR,
                              HistGradientBoostingRegressor as HGBR,
                              GradientBoostingRegressor as GBR,
                             );
from sklearn.neighbors import KNeighborsRegressor as KNNR;
from sklearn.svm import SVR;
from sklearn.linear_model import Ridge as RIDGER;

# Ensemble and tuning:-
import optuna;
from optuna import Trial, trial, create_study;
from optuna.samplers import TPESampler, CmaEsSampler;
optuna.logging.set_verbosity = optuna.logging.ERROR;

from sklego.linear_model import LADRegression as LADR;

clear_output();
print();
collect();
# Out:
# CPU times: user 1.74 s, sys: 161 ms, total: 1.9 s
# Wall time: 2.59 s

# %%
# %%time 

# Setting rc parameters in seaborn for plots and graphs- 
# Reference - https://matplotlib.org/stable/tutorials/introductory/customizing.html:-
# To alter this, refer to matplotlib.rcParams.keys()

sns.set({"axes.facecolor"       : "#ffffff",
         "figure.facecolor"     : "#ffffff",
         "axes.edgecolor"       : "#000000",
         "grid.color"           : "#ffffff",
         "font.family"          : ['Cambria'],
         "axes.labelcolor"      : "#000000",
         "xtick.color"          : "#000000",
         "ytick.color"          : "#000000",
         "grid.linewidth"       : 0.75,  
         "grid.linestyle"       : "--",
         "axes.titlecolor"      : '#0099e6',
         'axes.titlesize'       : 8.5,
         'axes.labelweight'     : "bold",
         'legend.fontsize'      : 7.0,
         'legend.title_fontsize': 7.0,
         'font.size'            : 7.5,
         'xtick.labelsize'      : 7.5,
         'ytick.labelsize'      : 7.5,        
        });

# Color printing    
def PrintColor(text:str, color = Fore.BLUE, style = Style.BRIGHT):
    "Prints color outputs using colorama using a text F-string";
    print(style + color + text + Style.RESET_ALL); 

# Making sklearn pipeline outputs as dataframe:-
from sklearn import set_config; 
set_config(transform_output = "pandas");
pd.set_option('display.max_columns', 50);
pd.set_option('display.max_rows', 50);

print();
collect();
# Out:
# CPU times: user 134 ms, sys: 655 µs, total: 134 ms
# Wall time: 134 ms

# %% [markdown]
# <a id="2"></a>
# # <div style= "font-family: Cambria; font-weight:bold; letter-spacing: 0px; color:black; font-size:120%; text-align:left;padding:3.0px; background: #cceeff; border-bottom: 8px solid #004466" > INTRODUCTION<br><div>

# %% [markdown]
# | Version<br>Number | Version Details | CV score| Single/ Ensemble|Public LB Score|
# | :-: | --- | :-: | :-: |:-:|
# | **V1** |* No scaling and null treatment <br> * No secondary features <br> * Used original data <br> * 5 x 2 RKF CV <br> * Tree based ML models and Optuna ensemble|0.543611|Optuna blend |0.51966|
# | **V2** |* No scaling and null treatment <br> * No secondary features <br> * Used original data <br> * Cleaned synthetic targets with target-scaling <br> * 5 x 2 RSKF CV with target encoding <br> * Tree based ML models and LAD ensemble|0.516996|LAD |0.49161|
# | **V3** |* No secondary features <br> * Used original data <br> * Cleaned synthetic targets and dropped duplicates in train set <br> * 5 x 2 RKF CV<br> * ML Models and LAD ensemble <br> * Post-processed with train-test duplicates|0.52585|LAD |0.49396|
# | **V4** |* Same as V3 <br> * Used target encoding and RSKF 5x2|0.52429|LAD |0.50145|
# | **V5** |* Same as V3 <br> * Used KFold 10x1 <br> * Used PowerTransformer||LAD ||

# %% [markdown]
# <a id="2.1"></a>
# ## <div style= "font-family: Cambria; font-weight:bold; letter-spacing: 0px; color:#ffffff; font-size:120%; text-align:left;padding:3.0px; background: #0059b3; border-bottom: 8px solid #e6e6e6" > CONFIGURATION<br><div>

# %%
# %%time

# Configuration class:-
class CFG:
    "Configuration class for parameters and CV strategy for tuning and training";
    
    # Data preparation:-   
    version_nb         = 4;
    test_req           = "N";
    test_sample_frac   = 0.025;
    gpu_switch         = "OFF"; 
    state              = 42;
    target             = 'Hardness';
    episode            = 25;
    path               = f"/kaggle/input/playground-series-s3e{episode}";
    orig_path          = f"/kaggle/input/prediction-of-mohs-hardness-with-machine-learning/jm79zfps6b-1/Mineral_Dataset_Supplementary_Info.csv";
    
    dtl_preproc_req    = "Y";
    adv_cv_req         = "N";
    ftre_plots_req     = 'N';
    ftre_imp_req       = "N";
    
    # Data transforms and scaling:-    
    conjoin_orig_data  = "Y";
    drop_nulls         = "Y";
    sec_ftre_req       = "N";
    scale_req          = "N";
    # NOTE---Keep a value here even if scale_req = N, this is used for linear models:-
    scl_method         = "PT"; 
    enc_method         = 'Label';
    OH_cols            = [];
    tgt_scl_fct        = 100;
    
    # Model Training:- 
    baseline_req       = "N";
    pstprcs_oof        = "Y";
    pstprcs_train      = "Y";
    pstprcs_test       = "Y";
    ML                 = "Y";
    
    pseudo_lbl_req     = "N";
    pseudolbl_up       = 0.90;
    pseudolbl_low      = 0.05;
    
    use_orig_allfolds  = "N";
    n_splits           = 10 ;
    n_repeats          = 1 ;
    nbrnd_erly_stp     = 50 ;
    mdlcv_mthd         = 'RKF';
    
    # Ensemble:-    
    ensemble_req       = "Y";
    hill_climb_req     = "N";
    optuna_req         = "N";
    LAD_req            = "Y";
    enscv_mthd         = "RKF";
    metric_obj         = 'minimize';
    ntrials            = 10 if test_req == "Y" else 500;
    
    # Global variables for plotting:-
    grid_specs = {'visible': True, 'which': 'both', 'linestyle': '--', 
                           'color': 'lightgrey', 'linewidth': 0.75};
    title_specs = {'fontsize': 9, 'fontweight': 'bold', 'color': 'tab:blue'};

print();
PrintColor(f"--> Configuration done!\n");
collect();
# Out:
# --> Configuration done!
#
# CPU times: user 132 ms, sys: 0 ns, total: 132 ms
# Wall time: 131 ms

# %%
# %%time 

# Defining functions to be used throughout the code for common tasks:-

# Scaler to be used for continuous columns:- 
all_scalers = {'Robust': RobustScaler(), 
               'Z': StandardScaler(), 
               'MinMax': MinMaxScaler(),
               "PT" : PowerTransformer(),
              };
scaler      = all_scalers.get(CFG.scl_method);

# Commonly used CV strategies for later usage:-
all_cv= {'KF'  : KFold(n_splits= CFG.n_splits, shuffle = True, random_state= CFG.state),
         'RKF' : RKF(n_splits= CFG.n_splits, n_repeats = CFG.n_repeats, random_state= CFG.state),
         'RSKF': RSKF(n_splits= CFG.n_splits, n_repeats = CFG.n_repeats, random_state= CFG.state),
         'SKF' : SKF(n_splits= CFG.n_splits, shuffle = True, random_state= CFG.state)
        };

# Defining the competition metric:-
def ScoreMetric(ytrue, ypred, tgt_scl_fct = CFG.tgt_scl_fct)-> float:
    """
    This function calculates the metric for the competition. 
    ytrue- ground truth array
    ypred- predictions
    returns - metric value (float)
    
    This function necessitates that the predictions array should be flattened.
    """;
    
    return medae(ytrue, ypred);

def PostProcessPred(preds, post_process = "N", tgt_scl_fct = CFG.tgt_scl_fct):
    """
    This is an optional post-processing function. 
    We correct predictions to be within the specific range
    """;
    if post_process == "Y":
        preds_pp = np.clip(preds, a_min = 0, a_max= 10 * tgt_scl_fct);
        return preds_pp;
    else:
        return preds;

# Designing a custom scorer to use in cross_val_predict and cross_val_score:-
myscorer = make_scorer(ScoreMetric, 
                       greater_is_better = False if CFG.metric_obj == "minimize" else True, 
                       needs_proba= False,
                      );

# Making a directory to store the model objects:-
if os.path.exists("/kaggle/working/MLModels") == True:
    PrintColor(f"\n---> MLModels already exists\n", color = Fore.RED);
else:
    os.mkdir("MLModels");
    PrintColor(f"\n---> Made directory MLModels to store models for inference\n", color = Fore.RED)


collect();
print();
# Out:
# ---> Made directory MLModels to store models for inference
#
#
# CPU times: user 133 ms, sys: 596 µs, total: 133 ms
# Wall time: 132 ms

# %% [markdown]
# <a id="2.2"></a>
# ## <div style= "font-family: Cambria; font-weight:bold; letter-spacing: 0px; color:#ffffff; font-size:120%; text-align:left;padding:3.0px; background: #0059b3; border-bottom: 8px solid #e6e6e6" > CONFIGURATION PARAMETERS<br><div>
#
#
# | Parameter         | Description                                             | Possible value choices|
# | ---               | ---                                                     | :-:                   |
# |  version_nb       | Version Number                                          | integer               |
# |  test_req         | Are we testing syntax here?                             | Y/N                   |
# |  test_sample_frac | Sample size for syntax test                             | float(0-1)/ int       |
# |  gpu_switch       | GPU switch                                              | ON/OFF                |
# |  state            | Random state for most purposes                          | integer               |
# |  target           | Target column name                                      | yield                 |
# |  episode          | Episode Number                                          | integer               |
# |  path             | Path for input data files                               |                       |
# |  orig_path        | Path for input original data files                      |                       |
# |  dtl_preproc_req  | Proprocessing required                                  | Y/N                   |
# |  adv_cv_req       | Adversarial CV required                                 | Y/N                   |
# |  ftre_plots_req   | Feature plots required                                  | Y/N                   |
# |  ftre_imp_req     | Feature importance required                             | Y/N                   |
# |  conjoin_orig_data| Conjoin original data                                   | Y/N                   |
# |  drop_nulls       | Drop original data nulls                                | Y/N                   |
# |  sec_ftre_req     | Secondary features required                             | Y/N                   |
# |  scale_req        | Scaling required                                        | Y/N                   |
# |  scl_method       | Scaling method                                          | Z/ Robust/ MinMax     |
# |  enc_method       | Encoding method                                         |-                      |
# |  OH_cols          | Onehot columns                                          |list                   |
# |  tgt_scl_fct      | Target scaling factor                                   |integer                |
# |  tgt_mapper       | Target mapper                                           | dict                  |
# |  drop_tr_req      | Drop extra training elements not in test                | Y/N                   |
# |  baseline_req     | Baseline model required                                 | Y/N                   |
# |  pstprcs_oof      | Post-process OOF after model training                   | Y/N                   |
# |  pstprcs_train    | Post-process OOF during model training for dev-set      | Y/N                   |
# |  pstprcs_test     | Post-process test after training                        | Y/N                   |
# |  ML               | Machine Learning Models                                 | Y/N                   |
# |  use_orig_all_folds| Use original data in all folds                         | Y/N                   |
# |  n_splits         | Number of CV splits                                     | integer               |
# |  n_repeats        | Number of CV repeats                                    | integer               |
# |  nbrnd_erly_stp   | Number of early stopping rounds                         | integer               |
# |  mdl_cv_mthd      | Model CV method name                                    | RKF/ RSKF/ SKF/ KFold |

# %% [markdown]
# <a id="2.3"></a>
# ## <div style= "font-family: Cambria; font-weight:bold; letter-spacing: 0px; color:#ffffff; font-size:120%; text-align:left;padding:3.0px; background: #0059b3; border-bottom: 8px solid #e6e6e6" > DATASET AND COMPETITION DETAILS<br><div>
#
# **Data columns**<br>
# This is available in the original data description as below<br>
# https://www.kaggle.com/datasets/gauravduttakiit/smoker-status-prediction-using-biosignals/ <br>
# <br>**Competition details and notebook objectives**<br>
# 1. This is a 2-class classification challenge to predict code related defects using the provided features. **GINI-score** is the metric for the challenge<br>
# 2. In this starter notebook, we start the assignment with a detailed EDA, feature plots, interaction effects, adversarial CV analysis and develop starter models to initiate the challenge. We will also incorporate other opinions and approaches as we move along the challenge.<br>

# %% [markdown]
# <a id="3"></a>
# # <div style= "font-family: Cambria; font-weight:bold; letter-spacing: 0px; color:black; font-size:120%; text-align:left;padding:3.0px; background: #cceeff; border-bottom: 8px solid #004466" > PREPROCESSING<br><div>

# %%
# %time 

class Preprocessor():
    """
    This class aims to do the below-
    1. Read the datasets
    2. In this case, process the original data
    3. Check information and description
    4. Check unique values and nulls
    5. Collate starting features 
    6. Conjoin train-original data if requested based on Adversarial CV results
    """;
    
    def __init__(self):
        self.train             = pd.read_csv(os.path.join(CFG.path,"train.csv"), index_col = 'id');
        self.test              = pd.read_csv(os.path.join(CFG.path ,"test.csv"), index_col = 'id');
        self.target            = CFG.target ;
        self.original          = pd.read_csv(CFG.orig_path);
        self.conjoin_orig_data = CFG.conjoin_orig_data;
        self.dtl_preproc_req   = CFG.dtl_preproc_req;
        self.test_req          = CFG.test_req;
        
        self.sub_fl   = pd.read_csv(os.path.join(CFG.path, "sample_submission.csv"));
        PrintColor(f"Data shapes - train-test-original = {self.train.shape} {self.test.shape} {self.original.shape}");
        
        for tbl in [self.train, self.original, self.test]:
            tbl.columns = tbl.columns.str.replace(r"\(|\)|\s+","", regex = True);
            tbl['allelectrons_Total'] = tbl['allelectrons_Total'].astype(np.uint16);
        
        PrintColor(f"\nTrain set head", color = Fore.GREEN);
        display(self.train.head(5).style.format(precision = 3));
        PrintColor(f"\nTest set head", color = Fore.GREEN);
        display(self.test.head(5).style.format(precision = 3));
        PrintColor(f"\nOriginal set head", color = Fore.GREEN);
        display(self.original.head(5).style.format(precision = 3));
                 
        # Resetting original data index:-
        self.original.index = range(len(self.original));
        self.original.index+= max(self.test.index) + 1;
        self.original.index.name = 'id';
        
        #  Changing original data column order to match the competition column structure:-
        self.original = self.original.reindex(self.train.columns, axis=1);
              
    def _AddSourceCol(self):
        self.train['Source'] = "Competition";
        self.test['Source']  = "Competition";
        self.original['Source'] = 'Original';
        
        self.strt_ftre = self.test.columns;
        return self;
          
    def _CollateInfoDesc(self):
        if self.dtl_preproc_req == "Y":
            PrintColor(f"\n{'-'*20} Information and description {'-'*20}\n", color = Fore.MAGENTA);

            # Creating dataset information and description:
            for lbl, df in {'Train': self.train, 'Test': self.test, 'Original': self.original}.items():
                PrintColor(f"\n{lbl} description\n");
                display(df.describe(percentiles= [0.05, 0.25, 0.50, 0.75, 0.9, 0.95, 0.99]).\
                        transpose().\
                        drop(columns = ['count'], errors = 'ignore').\
                        drop([CFG.target], axis=0, errors = 'ignore').\
                        style.format(formatter = '{:,.2f}').\
                        background_gradient(cmap = 'Blues')
                       );

                PrintColor(f"\n{lbl} information\n");
                display(df.info());
                collect();
        return self;
    
    def _CollateUnqNull(self):
        
        if self.dtl_preproc_req == "Y":
            # Dislaying the unique values across train-test-original:-
            PrintColor(f"\nUnique and null values\n");
            _ = pd.concat([self.train[self.strt_ftre].nunique(), 
                           self.test[self.strt_ftre].nunique(), 
                           self.original[self.strt_ftre].nunique(),
                           self.train[self.strt_ftre].isna().sum(axis=0),
                           self.test[self.strt_ftre].isna().sum(axis=0),
                           self.original[self.strt_ftre].isna().sum(axis=0)
                          ], 
                          axis=1);
            _.columns = ['Train_Nunq', 'Test_Nunq', 'Original_Nunq', 
                         'Train_Nulls', 'Test_Nulls', 'Original_Nulls'
                        ];

            display(_.T.style.background_gradient(cmap = 'Blues', axis=1).\
                    format(formatter = '{:,.0f}')
                   );
            
        return self;
       
    def DoPreprocessing(self):
        self._AddSourceCol();
        self._CollateInfoDesc();
        self._CollateUnqNull();
        
        return self; 
        
    def ConjoinTrainOrig(self):
        if self.conjoin_orig_data == "Y":
            PrintColor(f"Train shape before conjoining with original = {self.train.shape}");
            train = pd.concat([self.train, self.original], axis=0, ignore_index = True);
            PrintColor(f"Train shape after conjoining with original= {train.shape}");
            
            train = train.drop_duplicates();
            PrintColor(f"Train shape after de-duping = {train.shape}");
            
            train.index = range(len(train));
            train.index.name = 'id';
        
        else:
            PrintColor(f"We are using the competition training data only");
            train = self.train;
        return train;
          
collect();
print();
# Out:
# CPU times: user 3 µs, sys: 1 µs, total: 4 µs
# Wall time: 7.39 µs

# %%
# %%time 

pp = Preprocessor();
pp.DoPreprocessing();

if CFG.ensemble_req == "Y":
    sub_fl = pp.sub_fl.copy(deep = True);

print();
collect();
# Out:
# Data shapes - train-test-original = (10407, 12) (6939, 11) (622, 13)
#
# Train set head
# <style type="text/css">
# </style>
# <table id="T_cbdbc">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cbdbc_level0_col0" class="col_heading level0 col0" >allelectrons_Total</th>
#       <th id="T_cbdbc_level0_col1" class="col_heading level0 col1" >density_Total</th>
#       <th id="T_cbdbc_level0_col2" class="col_heading level0 col2" >allelectrons_Average</th>
#       <th id="T_cbdbc_level0_col3" class="col_heading level0 col3" >val_e_Average</th>
#       <th id="T_cbdbc_level0_col4" class="col_heading level0 col4" >atomicweight_Average</th>
#       <th id="T_cbdbc_level0_col5" class="col_heading level0 col5" >ionenergy_Average</th>
#       <th id="T_cbdbc_level0_col6" class="col_heading level0 col6" >el_neg_chi_Average</th>
#       <th id="T_cbdbc_level0_col7" class="col_heading level0 col7" >R_vdw_element_Average</th>
#       <th id="T_cbdbc_level0_col8" class="col_heading level0 col8" >R_cov_element_Average</th>
#       <th id="T_cbdbc_level0_col9" class="col_heading level0 col9" >zaratio_Average</th>
#       <th id="T_cbdbc_level0_col10" class="col_heading level0 col10" >density_Average</th>
#       <th id="T_cbdbc_level0_col11" class="col_heading level0 col11" >Hardness</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >id</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cbdbc_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_cbdbc_row0_col0" class="data row0 col0" >100</td>
#       <td id="T_cbdbc_row0_col1" class="data row0 col1" >0.842</td>
#       <td id="T_cbdbc_row0_col2" class="data row0 col2" >10.000</td>
#       <td id="T_cbdbc_row0_col3" class="data row0 col3" >4.800</td>
#       <td id="T_cbdbc_row0_col4" class="data row0 col4" >20.613</td>
#       <td id="T_cbdbc_row0_col5" class="data row0 col5" >11.088</td>
#       <td id="T_cbdbc_row0_col6" class="data row0 col6" >2.766</td>
#       <td id="T_cbdbc_row0_col7" class="data row0 col7" >1.732</td>
#       <td id="T_cbdbc_row0_col8" class="data row0 col8" >0.860</td>
#       <td id="T_cbdbc_row0_col9" class="data row0 col9" >0.496</td>
#       <td id="T_cbdbc_row0_col10" class="data row0 col10" >0.915</td>
#       <td id="T_cbdbc_row0_col11" class="data row0 col11" >6.000</td>
#     </tr>
#     <tr>
#       <th id="T_cbdbc_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_cbdbc_row1_col0" class="data row1 col0" >100</td>
#       <td id="T_cbdbc_row1_col1" class="data row1 col1" >7.558</td>
#       <td id="T_cbdbc_row1_col2" class="data row1 col2" >10.000</td>
#       <td id="T_cbdbc_row1_col3" class="data row1 col3" >4.800</td>
#       <td id="T_cbdbc_row1_col4" class="data row1 col4" >20.299</td>
#       <td id="T_cbdbc_row1_col5" class="data row1 col5" >12.041</td>
#       <td id="T_cbdbc_row1_col6" class="data row1 col6" >2.755</td>
#       <td id="T_cbdbc_row1_col7" class="data row1 col7" >1.631</td>
#       <td id="T_cbdbc_row1_col8" class="data row1 col8" >0.910</td>
#       <td id="T_cbdbc_row1_col9" class="data row1 col9" >0.493</td>
#       <td id="T_cbdbc_row1_col10" class="data row1 col10" >0.718</td>
#       <td id="T_cbdbc_row1_col11" class="data row1 col11" >6.500</td>
#     </tr>
#     <tr>
#       <th id="T_cbdbc_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_cbdbc_row2_col0" class="data row2 col0" >76</td>
#       <td id="T_cbdbc_row2_col1" class="data row2 col1" >8.886</td>
#       <td id="T_cbdbc_row2_col2" class="data row2 col2" >15.600</td>
#       <td id="T_cbdbc_row2_col3" class="data row2 col3" >5.600</td>
#       <td id="T_cbdbc_row2_col4" class="data row2 col4" >33.739</td>
#       <td id="T_cbdbc_row2_col5" class="data row2 col5" >12.086</td>
#       <td id="T_cbdbc_row2_col6" class="data row2 col6" >2.828</td>
#       <td id="T_cbdbc_row2_col7" class="data row2 col7" >1.788</td>
#       <td id="T_cbdbc_row2_col8" class="data row2 col8" >0.864</td>
#       <td id="T_cbdbc_row2_col9" class="data row2 col9" >0.481</td>
#       <td id="T_cbdbc_row2_col10" class="data row2 col10" >1.506</td>
#       <td id="T_cbdbc_row2_col11" class="data row2 col11" >2.500</td>
#     </tr>
#     <tr>
#       <th id="T_cbdbc_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_cbdbc_row3_col0" class="data row3 col0" >100</td>
#       <td id="T_cbdbc_row3_col1" class="data row3 col1" >8.795</td>
#       <td id="T_cbdbc_row3_col2" class="data row3 col2" >10.000</td>
#       <td id="T_cbdbc_row3_col3" class="data row3 col3" >4.800</td>
#       <td id="T_cbdbc_row3_col4" class="data row3 col4" >20.213</td>
#       <td id="T_cbdbc_row3_col5" class="data row3 col5" >10.948</td>
#       <td id="T_cbdbc_row3_col6" class="data row3 col6" >2.648</td>
#       <td id="T_cbdbc_row3_col7" class="data row3 col7" >1.626</td>
#       <td id="T_cbdbc_row3_col8" class="data row3 col8" >0.936</td>
#       <td id="T_cbdbc_row3_col9" class="data row3 col9" >0.489</td>
#       <td id="T_cbdbc_row3_col10" class="data row3 col10" >0.789</td>
#       <td id="T_cbdbc_row3_col11" class="data row3 col11" >6.000</td>
#     </tr>
#     <tr>
#       <th id="T_cbdbc_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_cbdbc_row4_col0" class="data row4 col0" >116</td>
#       <td id="T_cbdbc_row4_col1" class="data row4 col1" >9.578</td>
#       <td id="T_cbdbc_row4_col2" class="data row4 col2" >11.600</td>
#       <td id="T_cbdbc_row4_col3" class="data row4 col3" >4.800</td>
#       <td id="T_cbdbc_row4_col4" class="data row4 col4" >24.988</td>
#       <td id="T_cbdbc_row4_col5" class="data row4 col5" >11.824</td>
#       <td id="T_cbdbc_row4_col6" class="data row4 col6" >2.766</td>
#       <td id="T_cbdbc_row4_col7" class="data row4 col7" >1.682</td>
#       <td id="T_cbdbc_row4_col8" class="data row4 col8" >0.896</td>
#       <td id="T_cbdbc_row4_col9" class="data row4 col9" >0.493</td>
#       <td id="T_cbdbc_row4_col10" class="data row4 col10" >1.865</td>
#       <td id="T_cbdbc_row4_col11" class="data row4 col11" >6.000</td>
#     </tr>
#   </tbody>
# </table>
# Test set head
# <style type="text/css">
# </style>
# <table id="T_b2a61">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b2a61_level0_col0" class="col_heading level0 col0" >allelectrons_Total</th>
#       <th id="T_b2a61_level0_col1" class="col_heading level0 col1" >density_Total</th>
#       <th id="T_b2a61_level0_col2" class="col_heading level0 col2" >allelectrons_Average</th>
#       <th id="T_b2a61_level0_col3" class="col_heading level0 col3" >val_e_Average</th>
#       <th id="T_b2a61_level0_col4" class="col_heading level0 col4" >atomicweight_Average</th>
#       <th id="T_b2a61_level0_col5" class="col_heading level0 col5" >ionenergy_Average</th>
#       <th id="T_b2a61_level0_col6" class="col_heading level0 col6" >el_neg_chi_Average</th>
#       <th id="T_b2a61_level0_col7" class="col_heading level0 col7" >R_vdw_element_Average</th>
#       <th id="T_b2a61_level0_col8" class="col_heading level0 col8" >R_cov_element_Average</th>
#       <th id="T_b2a61_level0_col9" class="col_heading level0 col9" >zaratio_Average</th>
#       <th id="T_b2a61_level0_col10" class="col_heading level0 col10" >density_Average</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >id</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b2a61_level0_row0" class="row_heading level0 row0" >10407</th>
#       <td id="T_b2a61_row0_col0" class="data row0 col0" >884</td>
#       <td id="T_b2a61_row0_col1" class="data row0 col1" >121.420</td>
#       <td id="T_b2a61_row0_col2" class="data row0 col2" >35.360</td>
#       <td id="T_b2a61_row0_col3" class="data row0 col3" >5.280</td>
#       <td id="T_b2a61_row0_col4" class="data row0 col4" >82.561</td>
#       <td id="T_b2a61_row0_col5" class="data row0 col5" >9.370</td>
#       <td id="T_b2a61_row0_col6" class="data row0 col6" >2.298</td>
#       <td id="T_b2a61_row0_col7" class="data row0 col7" >1.907</td>
#       <td id="T_b2a61_row0_col8" class="data row0 col8" >1.200</td>
#       <td id="T_b2a61_row0_col9" class="data row0 col9" >0.462</td>
#       <td id="T_b2a61_row0_col10" class="data row0 col10" >1.795</td>
#     </tr>
#     <tr>
#       <th id="T_b2a61_level0_row1" class="row_heading level0 row1" >10408</th>
#       <td id="T_b2a61_row1_col0" class="data row1 col0" >90</td>
#       <td id="T_b2a61_row1_col1" class="data row1 col1" >9.932</td>
#       <td id="T_b2a61_row1_col2" class="data row1 col2" >18.000</td>
#       <td id="T_b2a61_row1_col3" class="data row1 col3" >5.600</td>
#       <td id="T_b2a61_row1_col4" class="data row1 col4" >39.568</td>
#       <td id="T_b2a61_row1_col5" class="data row1 col5" >12.086</td>
#       <td id="T_b2a61_row1_col6" class="data row1 col6" >2.868</td>
#       <td id="T_b2a61_row1_col7" class="data row1 col7" >1.652</td>
#       <td id="T_b2a61_row1_col8" class="data row1 col8" >0.864</td>
#       <td id="T_b2a61_row1_col9" class="data row1 col9" >0.476</td>
#       <td id="T_b2a61_row1_col10" class="data row1 col10" >1.412</td>
#     </tr>
#     <tr>
#       <th id="T_b2a61_level0_row2" class="row_heading level0 row2" >10409</th>
#       <td id="T_b2a61_row2_col0" class="data row2 col0" >116</td>
#       <td id="T_b2a61_row2_col1" class="data row2 col1" >7.768</td>
#       <td id="T_b2a61_row2_col2" class="data row2 col2" >11.600</td>
#       <td id="T_b2a61_row2_col3" class="data row2 col3" >4.800</td>
#       <td id="T_b2a61_row2_col4" class="data row2 col4" >23.232</td>
#       <td id="T_b2a61_row2_col5" class="data row2 col5" >11.024</td>
#       <td id="T_b2a61_row2_col6" class="data row2 col6" >2.644</td>
#       <td id="T_b2a61_row2_col7" class="data row2 col7" >1.794</td>
#       <td id="T_b2a61_row2_col8" class="data row2 col8" >0.960</td>
#       <td id="T_b2a61_row2_col9" class="data row2 col9" >0.500</td>
#       <td id="T_b2a61_row2_col10" class="data row2 col10" >0.788</td>
#     </tr>
#     <tr>
#       <th id="T_b2a61_level0_row3" class="row_heading level0 row3" >10410</th>
#       <td id="T_b2a61_row3_col0" class="data row3 col0" >100</td>
#       <td id="T_b2a61_row3_col1" class="data row3 col1" >9.108</td>
#       <td id="T_b2a61_row3_col2" class="data row3 col2" >10.000</td>
#       <td id="T_b2a61_row3_col3" class="data row3 col3" >4.800</td>
#       <td id="T_b2a61_row3_col4" class="data row3 col4" >20.299</td>
#       <td id="T_b2a61_row3_col5" class="data row3 col5" >12.086</td>
#       <td id="T_b2a61_row3_col6" class="data row3 col6" >2.828</td>
#       <td id="T_b2a61_row3_col7" class="data row3 col7" >1.662</td>
#       <td id="T_b2a61_row3_col8" class="data row3 col8" >0.792</td>
#       <td id="T_b2a61_row3_col9" class="data row3 col9" >0.496</td>
#       <td id="T_b2a61_row3_col10" class="data row3 col10" >1.205</td>
#     </tr>
#     <tr>
#       <th id="T_b2a61_level0_row4" class="row_heading level0 row4" >10411</th>
#       <td id="T_b2a61_row4_col0" class="data row4 col0" >55</td>
#       <td id="T_b2a61_row4_col1" class="data row4 col1" >4.030</td>
#       <td id="T_b2a61_row4_col2" class="data row4 col2" >11.000</td>
#       <td id="T_b2a61_row4_col3" class="data row4 col3" >4.000</td>
#       <td id="T_b2a61_row4_col4" class="data row4 col4" >22.978</td>
#       <td id="T_b2a61_row4_col5" class="data row4 col5" >11.281</td>
#       <td id="T_b2a61_row4_col6" class="data row4 col6" >2.455</td>
#       <td id="T_b2a61_row4_col7" class="data row4 col7" >1.750</td>
#       <td id="T_b2a61_row4_col8" class="data row4 col8" >0.893</td>
#       <td id="T_b2a61_row4_col9" class="data row4 col9" >0.476</td>
#       <td id="T_b2a61_row4_col10" class="data row4 col10" >0.935</td>
#     </tr>
#   </tbody>
# </table>
# Original set head
# <style type="text/css">
# </style>
# <table id="T_f20aa">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f20aa_level0_col0" class="col_heading level0 col0" >Unnamed:0</th>
#       <th id="T_f20aa_level0_col1" class="col_heading level0 col1" >Hardness</th>
#       <th id="T_f20aa_level0_col2" class="col_heading level0 col2" >allelectrons_Total</th>
#       <th id="T_f20aa_level0_col3" class="col_heading level0 col3" >density_Total</th>
#       <th id="T_f20aa_level0_col4" class="col_heading level0 col4" >allelectrons_Average</th>
#       <th id="T_f20aa_level0_col5" class="col_heading level0 col5" >val_e_Average</th>
#       <th id="T_f20aa_level0_col6" class="col_heading level0 col6" >atomicweight_Average</th>
#       <th id="T_f20aa_level0_col7" class="col_heading level0 col7" >ionenergy_Average</th>
#       <th id="T_f20aa_level0_col8" class="col_heading level0 col8" >el_neg_chi_Average</th>
#       <th id="T_f20aa_level0_col9" class="col_heading level0 col9" >R_vdw_element_Average</th>
#       <th id="T_f20aa_level0_col10" class="col_heading level0 col10" >R_cov_element_Average</th>
#       <th id="T_f20aa_level0_col11" class="col_heading level0 col11" >zaratio_Average</th>
#       <th id="T_f20aa_level0_col12" class="col_heading level0 col12" >density_Average</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f20aa_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f20aa_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_f20aa_row0_col1" class="data row0 col1" >2.300</td>
#       <td id="T_f20aa_row0_col2" class="data row0 col2" >110</td>
#       <td id="T_f20aa_row0_col3" class="data row0 col3" >23.000</td>
#       <td id="T_f20aa_row0_col4" class="data row0 col4" >36.667</td>
#       <td id="T_f20aa_row0_col5" class="data row0 col5" >2.667</td>
#       <td id="T_f20aa_row0_col6" class="data row0 col6" >82.598</td>
#       <td id="T_f20aa_row0_col7" class="data row0 col7" >8.504</td>
#       <td id="T_f20aa_row0_col8" class="data row0 col8" >2.147</td>
#       <td id="T_f20aa_row0_col9" class="data row0 col9" >2.007</td>
#       <td id="T_f20aa_row0_col10" class="data row0 col10" >1.253</td>
#       <td id="T_f20aa_row0_col11" class="data row0 col11" >0.457</td>
#       <td id="T_f20aa_row0_col12" class="data row0 col12" >7.667</td>
#     </tr>
#     <tr>
#       <th id="T_f20aa_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f20aa_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_f20aa_row1_col1" class="data row1 col1" >5.500</td>
#       <td id="T_f20aa_row1_col2" class="data row1 col2" >406</td>
#       <td id="T_f20aa_row1_col3" class="data row1 col3" >30.472</td>
#       <td id="T_f20aa_row1_col4" class="data row1 col4" >9.902</td>
#       <td id="T_f20aa_row1_col5" class="data row1 col5" >4.683</td>
#       <td id="T_f20aa_row1_col6" class="data row1 col6" >19.813</td>
#       <td id="T_f20aa_row1_col7" class="data row1 col7" >11.456</td>
#       <td id="T_f20aa_row1_col8" class="data row1 col8" >2.700</td>
#       <td id="T_f20aa_row1_col9" class="data row1 col9" >1.677</td>
#       <td id="T_f20aa_row1_col10" class="data row1 col10" >0.868</td>
#       <td id="T_f20aa_row1_col11" class="data row1 col11" >0.523</td>
#       <td id="T_f20aa_row1_col12" class="data row1 col12" >0.743</td>
#     </tr>
#     <tr>
#       <th id="T_f20aa_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f20aa_row2_col0" class="data row2 col0" >2</td>
#       <td id="T_f20aa_row2_col1" class="data row2 col1" >5.500</td>
#       <td id="T_f20aa_row2_col2" class="data row2 col2" >406</td>
#       <td id="T_f20aa_row2_col3" class="data row2 col3" >30.472</td>
#       <td id="T_f20aa_row2_col4" class="data row2 col4" >10.410</td>
#       <td id="T_f20aa_row2_col5" class="data row2 col5" >4.923</td>
#       <td id="T_f20aa_row2_col6" class="data row2 col6" >20.931</td>
#       <td id="T_f20aa_row2_col7" class="data row2 col7" >11.541</td>
#       <td id="T_f20aa_row2_col8" class="data row2 col8" >2.754</td>
#       <td id="T_f20aa_row2_col9" class="data row2 col9" >1.704</td>
#       <td id="T_f20aa_row2_col10" class="data row2 col10" >0.894</td>
#       <td id="T_f20aa_row2_col11" class="data row2 col11" >0.497</td>
#       <td id="T_f20aa_row2_col12" class="data row2 col12" >0.781</td>
#     </tr>
#     <tr>
#       <th id="T_f20aa_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_f20aa_row3_col0" class="data row3 col0" >3</td>
#       <td id="T_f20aa_row3_col1" class="data row3 col1" >5.500</td>
#       <td id="T_f20aa_row3_col2" class="data row3 col2" >476</td>
#       <td id="T_f20aa_row3_col3" class="data row3 col3" >61.142</td>
#       <td id="T_f20aa_row3_col4" class="data row3 col4" >11.610</td>
#       <td id="T_f20aa_row3_col5" class="data row3 col5" >4.683</td>
#       <td id="T_f20aa_row3_col6" class="data row3 col6" >23.660</td>
#       <td id="T_f20aa_row3_col7" class="data row3 col7" >11.487</td>
#       <td id="T_f20aa_row3_col8" class="data row3 col8" >2.764</td>
#       <td id="T_f20aa_row3_col9" class="data row3 col9" >1.715</td>
#       <td id="T_f20aa_row3_col10" class="data row3 col10" >0.849</td>
#       <td id="T_f20aa_row3_col11" class="data row3 col11" >0.519</td>
#       <td id="T_f20aa_row3_col12" class="data row3 col12" >1.491</td>
#     </tr>
#     <tr>
#       <th id="T_f20aa_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_f20aa_row4_col0" class="data row4 col0" >4</td>
#       <td id="T_f20aa_row4_col1" class="data row4 col1" >5.500</td>
#       <td id="T_f20aa_row4_col2" class="data row4 col2" >476</td>
#       <td id="T_f20aa_row4_col3" class="data row4 col3" >61.142</td>
#       <td id="T_f20aa_row4_col4" class="data row4 col4" >12.205</td>
#       <td id="T_f20aa_row4_col5" class="data row4 col5" >4.923</td>
#       <td id="T_f20aa_row4_col6" class="data row4 col6" >24.975</td>
#       <td id="T_f20aa_row4_col7" class="data row4 col7" >11.574</td>
#       <td id="T_f20aa_row4_col8" class="data row4 col8" >2.820</td>
#       <td id="T_f20aa_row4_col9" class="data row4 col9" >1.744</td>
#       <td id="T_f20aa_row4_col10" class="data row4 col10" >0.874</td>
#       <td id="T_f20aa_row4_col11" class="data row4 col11" >0.494</td>
#       <td id="T_f20aa_row4_col12" class="data row4 col12" >1.568</td>
#     </tr>
#   </tbody>
# </table>
# -------------------- Information and description --------------------
#
#
# Train description
# <style type="text/css">
# #T_f671e_row0_col0, #T_f671e_row0_col1, #T_f671e_row0_col3, #T_f671e_row0_col4, #T_f671e_row0_col5, #T_f671e_row0_col6, #T_f671e_row0_col7, #T_f671e_row0_col8, #T_f671e_row0_col9, #T_f671e_row0_col10 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_f671e_row0_col2, #T_f671e_row1_col2, #T_f671e_row2_col2, #T_f671e_row3_col1, #T_f671e_row3_col2, #T_f671e_row3_col10, #T_f671e_row4_col2, #T_f671e_row5_col2, #T_f671e_row5_col10, #T_f671e_row6_col1, #T_f671e_row6_col2, #T_f671e_row6_col9, #T_f671e_row6_col10, #T_f671e_row7_col1, #T_f671e_row7_col2, #T_f671e_row7_col9, #T_f671e_row7_col10, #T_f671e_row8_col0, #T_f671e_row8_col1, #T_f671e_row8_col2, #T_f671e_row8_col6, #T_f671e_row8_col7, #T_f671e_row8_col8, #T_f671e_row8_col9, #T_f671e_row8_col10, #T_f671e_row9_col0, #T_f671e_row9_col1, #T_f671e_row9_col2, #T_f671e_row9_col3, #T_f671e_row9_col4, #T_f671e_row9_col5, #T_f671e_row9_col6, #T_f671e_row9_col7, #T_f671e_row9_col8, #T_f671e_row9_col9, #T_f671e_row9_col10, #T_f671e_row10_col2, #T_f671e_row10_col3, #T_f671e_row10_col10 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_f671e_row1_col0 {
#   background-color: #e1edf8;
#   color: #000000;
# }
# #T_f671e_row1_col1 {
#   background-color: #e9f2fa;
#   color: #000000;
# }
# #T_f671e_row1_col3, #T_f671e_row3_col4, #T_f671e_row5_col7 {
#   background-color: #edf4fc;
#   color: #000000;
# }
# #T_f671e_row1_col4, #T_f671e_row1_col5, #T_f671e_row1_col9 {
#   background-color: #e3eef8;
#   color: #000000;
# }
# #T_f671e_row1_col6, #T_f671e_row2_col5 {
#   background-color: #dfebf7;
#   color: #000000;
# }
# #T_f671e_row1_col7 {
#   background-color: #dfecf7;
#   color: #000000;
# }
# #T_f671e_row1_col8, #T_f671e_row2_col0 {
#   background-color: #ddeaf7;
#   color: #000000;
# }
# #T_f671e_row1_col10, #T_f671e_row3_col5, #T_f671e_row5_col8 {
#   background-color: #eff6fc;
#   color: #000000;
# }
# #T_f671e_row2_col1, #T_f671e_row6_col3 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_f671e_row2_col3 {
#   background-color: #d0e2f2;
#   color: #000000;
# }
# #T_f671e_row2_col4 {
#   background-color: #dbe9f6;
#   color: #000000;
# }
# #T_f671e_row2_col6, #T_f671e_row4_col9 {
#   background-color: #d6e6f4;
#   color: #000000;
# }
# #T_f671e_row2_col7 {
#   background-color: #dce9f6;
#   color: #000000;
# }
# #T_f671e_row2_col8, #T_f671e_row5_col4 {
#   background-color: #d9e8f5;
#   color: #000000;
# }
# #T_f671e_row2_col9 {
#   background-color: #eaf2fb;
#   color: #000000;
# }
# #T_f671e_row2_col10, #T_f671e_row3_col9, #T_f671e_row5_col1, #T_f671e_row7_col7, #T_f671e_row7_col8, #T_f671e_row8_col3, #T_f671e_row8_col4, #T_f671e_row8_col5, #T_f671e_row10_col4 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_f671e_row3_col0, #T_f671e_row3_col6 {
#   background-color: #f1f7fd;
#   color: #000000;
# }
# #T_f671e_row3_col3, #T_f671e_row5_col6 {
#   background-color: #e7f0fa;
#   color: #000000;
# }
# #T_f671e_row3_col7, #T_f671e_row6_col5, #T_f671e_row10_col7, #T_f671e_row10_col8 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_f671e_row3_col8, #T_f671e_row5_col9, #T_f671e_row6_col0, #T_f671e_row6_col6, #T_f671e_row7_col4, #T_f671e_row10_col6 {
#   background-color: #f4f9fe;
#   color: #000000;
# }
# #T_f671e_row4_col0 {
#   background-color: #b9d6ea;
#   color: #000000;
# }
# #T_f671e_row4_col1 {
#   background-color: #e0ecf8;
#   color: #000000;
# }
# #T_f671e_row4_col3 {
#   background-color: #91c3de;
#   color: #000000;
# }
# #T_f671e_row4_col4 {
#   background-color: #b8d5ea;
#   color: #000000;
# }
# #T_f671e_row4_col5 {
#   background-color: #c3daee;
#   color: #000000;
# }
# #T_f671e_row4_col6 {
#   background-color: #a0cbe2;
#   color: #000000;
# }
# #T_f671e_row4_col7 {
#   background-color: #b0d2e7;
#   color: #000000;
# }
# #T_f671e_row4_col8 {
#   background-color: #a5cde3;
#   color: #000000;
# }
# #T_f671e_row4_col10, #T_f671e_row6_col7, #T_f671e_row6_col8, #T_f671e_row7_col0, #T_f671e_row7_col6, #T_f671e_row10_col1, #T_f671e_row10_col5, #T_f671e_row10_col9 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_f671e_row5_col0 {
#   background-color: #e7f1fa;
#   color: #000000;
# }
# #T_f671e_row5_col3 {
#   background-color: #c8dcf0;
#   color: #000000;
# }
# #T_f671e_row5_col5 {
#   background-color: #e2edf8;
#   color: #000000;
# }
# #T_f671e_row6_col4, #T_f671e_row7_col3 {
#   background-color: #f2f7fd;
#   color: #000000;
# }
# #T_f671e_row7_col5, #T_f671e_row10_col0 {
#   background-color: #f5f9fe;
#   color: #000000;
# }
# </style>
# <table id="T_f671e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f671e_level0_col0" class="col_heading level0 col0" >mean</th>
#       <th id="T_f671e_level0_col1" class="col_heading level0 col1" >std</th>
#       <th id="T_f671e_level0_col2" class="col_heading level0 col2" >min</th>
#       <th id="T_f671e_level0_col3" class="col_heading level0 col3" >5%</th>
#       <th id="T_f671e_level0_col4" class="col_heading level0 col4" >25%</th>
#       <th id="T_f671e_level0_col5" class="col_heading level0 col5" >50%</th>
#       <th id="T_f671e_level0_col6" class="col_heading level0 col6" >75%</th>
#       <th id="T_f671e_level0_col7" class="col_heading level0 col7" >90%</th>
#       <th id="T_f671e_level0_col8" class="col_heading level0 col8" >95%</th>
#       <th id="T_f671e_level0_col9" class="col_heading level0 col9" >99%</th>
#       <th id="T_f671e_level0_col10" class="col_heading level0 col10" >max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f671e_level0_row0" class="row_heading level0 row0" >allelectrons_Total</th>
#       <td id="T_f671e_row0_col0" class="data row0 col0" >128.05</td>
#       <td id="T_f671e_row0_col1" class="data row0 col1" >224.12</td>
#       <td id="T_f671e_row0_col2" class="data row0 col2" >0.00</td>
#       <td id="T_f671e_row0_col3" class="data row0 col3" >36.00</td>
#       <td id="T_f671e_row0_col4" class="data row0 col4" >68.00</td>
#       <td id="T_f671e_row0_col5" class="data row0 col5" >100.00</td>
#       <td id="T_f671e_row0_col6" class="data row0 col6" >131.00</td>
#       <td id="T_f671e_row0_col7" class="data row0 col7" >222.00</td>
#       <td id="T_f671e_row0_col8" class="data row0 col8" >278.00</td>
#       <td id="T_f671e_row0_col9" class="data row0 col9" >719.40</td>
#       <td id="T_f671e_row0_col10" class="data row0 col10" >15,300.00</td>
#     </tr>
#     <tr>
#       <th id="T_f671e_level0_row1" class="row_heading level0 row1" >density_Total</th>
#       <td id="T_f671e_row1_col0" class="data row1 col0" >14.49</td>
#       <td id="T_f671e_row1_col1" class="data row1 col1" >15.97</td>
#       <td id="T_f671e_row1_col2" class="data row1 col2" >0.00</td>
#       <td id="T_f671e_row1_col3" class="data row1 col3" >2.33</td>
#       <td id="T_f671e_row1_col4" class="data row1 col4" >7.56</td>
#       <td id="T_f671e_row1_col5" class="data row1 col5" >10.65</td>
#       <td id="T_f671e_row1_col6" class="data row1 col6" >16.68</td>
#       <td id="T_f671e_row1_col7" class="data row1 col7" >27.10</td>
#       <td id="T_f671e_row1_col8" class="data row1 col8" >37.01</td>
#       <td id="T_f671e_row1_col9" class="data row1 col9" >75.10</td>
#       <td id="T_f671e_row1_col10" class="data row1 col10" >643.09</td>
#     </tr>
#     <tr>
#       <th id="T_f671e_level0_row2" class="row_heading level0 row2" >allelectrons_Average</th>
#       <td id="T_f671e_row2_col0" class="data row2 col0" >17.03</td>
#       <td id="T_f671e_row2_col1" class="data row2 col1" >10.47</td>
#       <td id="T_f671e_row2_col2" class="data row2 col2" >0.00</td>
#       <td id="T_f671e_row2_col3" class="data row2 col3" >7.50</td>
#       <td id="T_f671e_row2_col4" class="data row2 col4" >10.00</td>
#       <td id="T_f671e_row2_col5" class="data row2 col5" >12.60</td>
#       <td id="T_f671e_row2_col6" class="data row2 col6" >22.00</td>
#       <td id="T_f671e_row2_col7" class="data row2 col7" >31.33</td>
#       <td id="T_f671e_row2_col8" class="data row2 col8" >42.00</td>
#       <td id="T_f671e_row2_col9" class="data row2 col9" >50.00</td>
#       <td id="T_f671e_row2_col10" class="data row2 col10" >67.00</td>
#     </tr>
#     <tr>
#       <th id="T_f671e_level0_row3" class="row_heading level0 row3" >val_e_Average</th>
#       <td id="T_f671e_row3_col0" class="data row3 col0" >4.55</td>
#       <td id
# Train information
#
# <class 'pandas.core.frame.DataFrame'>
# Index: 10407 entries, 0 to 10406
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   allelectrons_Total     10407 non-null  uint16
#  1   density_Total          10407 non-null  float64
#  2   allelectrons_Average   10407 non-null  float64
#  3   val_e_Average          10407 non-null  float64
#  4   atomicweight_Average   10407 non-null  float64
#  5   ionenergy_Average      10407 non-null  float64
#  6   el_neg_chi_Average     10407 non-null  float64
#  7   R_vdw_element_Average  10407 non-null  float64
#  8   R_cov_element_Average  10407 non-null  float64
#  9   zaratio_Average        10407 non-null  float64
#  10  density_Average        10407 non-null  float64
#  11  Hardness               10407 non-null  float64
#  12  Source                 10407 non-null  object
# dtypes: float64(11), object(1), uint16(1)
# memory usage: 1.1+ MB
# None
# Test description
# <style type="text/css">
# #T_9e71a_row0_col0, #T_9e71a_row0_col1, #T_9e71a_row0_col3, #T_9e71a_row0_col4, #T_9e71a_row0_col5, #T_9e71a_row0_col6, #T_9e71a_row0_col7, #T_9e71a_row0_col8, #T_9e71a_row0_col9, #T_9e71a_row0_col10 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_9e71a_row0_col2, #T_9e71a_row1_col2, #T_9e71a_row2_col2, #T_9e71a_row3_col1, #T_9e71a_row3_col2, #T_9e71a_row3_col10, #T_9e71a_row4_col2, #T_9e71a_row5_col2, #T_9e71a_row5_col10, #T_9e71a_row6_col1, #T_9e71a_row6_col2, #T_9e71a_row6_col9, #T_9e71a_row6_col10, #T_9e71a_row7_col1, #T_9e71a_row7_col2, #T_9e71a_row7_col9, #T_9e71a_row7_col10, #T_9e71a_row8_col0, #T_9e71a_row8_col1, #T_9e71a_row8_col2, #T_9e71a_row8_col6, #T_9e71a_row8_col7, #T_9e71a_row8_col8, #T_9e71a_row8_col9, #T_9e71a_row8_col10, #T_9e71a_row9_col0, #T_9e71a_row9_col1, #T_9e71a_row9_col2, #T_9e71a_row9_col3, #T_9e71a_row9_col4, #T_9e71a_row9_col5, #T_9e71a_row9_col6, #T_9e71a_row9_col7, #T_9e71a_row9_col8, #T_9e71a_row9_col9, #T_9e71a_row9_col10, #T_9e71a_row10_col2, #T_9e71a_row10_col3, #T_9e71a_row10_col10 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_9e71a_row1_col0 {
#   background-color: #e0ecf8;
#   color: #000000;
# }
# #T_9e71a_row1_col1 {
#   background-color: #e5eff9;
#   color: #000000;
# }
# #T_9e71a_row1_col3 {
#   background-color: #ecf4fb;
#   color: #000000;
# }
# #T_9e71a_row1_col4, #T_9e71a_row1_col5 {
#   background-color: #e3eef8;
#   color: #000000;
# }
# #T_9e71a_row1_col6 {
#   background-color: #deebf7;
#   color: #000000;
# }
# #T_9e71a_row1_col7, #T_9e71a_row2_col5 {
#   background-color: #dfebf7;
#   color: #000000;
# }
# #T_9e71a_row1_col8, #T_9e71a_row2_col0 {
#   background-color: #dceaf6;
#   color: #000000;
# }
# #T_9e71a_row1_col9 {
#   background-color: #dae8f6;
#   color: #000000;
# }
# #T_9e71a_row1_col10 {
#   background-color: #eaf3fb;
#   color: #000000;
# }
# #T_9e71a_row2_col1, #T_9e71a_row3_col4, #T_9e71a_row5_col7 {
#   background-color: #edf4fc;
#   color: #000000;
# }
# #T_9e71a_row2_col3 {
#   background-color: #cddff1;
#   color: #000000;
# }
# #T_9e71a_row2_col4, #T_9e71a_row2_col7 {
#   background-color: #dbe9f6;
#   color: #000000;
# }
# #T_9e71a_row2_col6 {
#   background-color: #d6e5f4;
#   color: #000000;
# }
# #T_9e71a_row2_col8, #T_9e71a_row5_col4 {
#   background-color: #d9e8f5;
#   color: #000000;
# }
# #T_9e71a_row2_col9 {
#   background-color: #eaf2fb;
#   color: #000000;
# }
# #T_9e71a_row2_col10, #T_9e71a_row3_col9, #T_9e71a_row5_col1, #T_9e71a_row7_col7, #T_9e71a_row7_col8, #T_9e71a_row8_col4, #T_9e71a_row8_col5, #T_9e71a_row10_col4 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_9e71a_row3_col0, #T_9e71a_row3_col6, #T_9e71a_row7_col3 {
#   background-color: #f1f7fd;
#   color: #000000;
# }
# #T_9e71a_row3_col3 {
#   background-color: #e4eff9;
#   color: #000000;
# }
# #T_9e71a_row3_col5, #T_9e71a_row5_col8 {
#   background-color: #eff6fc;
#   color: #000000;
# }
# #T_9e71a_row3_col7, #T_9e71a_row6_col5, #T_9e71a_row10_col7, #T_9e71a_row10_col8 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_9e71a_row3_col8, #T_9e71a_row4_col10, #T_9e71a_row5_col9, #T_9e71a_row6_col0, #T_9e71a_row6_col6, #T_9e71a_row7_col4, #T_9e71a_row10_col6 {
#   background-color: #f4f9fe;
#   color: #000000;
# }
# #T_9e71a_row4_col0 {
#   background-color: #b5d4e9;
#   color: #000000;
# }
# #T_9e71a_row4_col1 {
#   background-color: #ddeaf7;
#   color: #000000;
# }
# #T_9e71a_row4_col3 {
#   background-color: #81badb;
#   color: #000000;
# }
# #T_9e71a_row4_col4 {
#   background-color: #b8d5ea;
#   color: #000000;
# }
# #T_9e71a_row4_col5, #T_9e71a_row5_col3 {
#   background-color: #c3daee;
#   color: #000000;
# }
# #T_9e71a_row4_col6 {
#   background-color: #9dcae1;
#   color: #000000;
# }
# #T_9e71a_row4_col7 {
#   background-color: #abd0e6;
#   color: #000000;
# }
# #T_9e71a_row4_col8 {
#   background-color: #a0cbe2;
#   color: #000000;
# }
# #T_9e71a_row4_col9 {
#   background-color: #d6e6f4;
#   color: #000000;
# }
# #T_9e71a_row5_col0 {
#   background-color: #e7f0fa;
#   color: #000000;
# }
# #T_9e71a_row5_col5 {
#   background-color: #e2edf8;
#   color: #000000;
# }
# #T_9e71a_row5_col6 {
#   background-color: #e6f0f9;
#   color: #000000;
# }
# #T_9e71a_row6_col3 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_9e71a_row6_col4 {
#   background-color: #f2f7fd;
#   color: #000000;
# }
# #T_9e71a_row6_col7, #T_9e71a_row6_col8, #T_9e71a_row7_col0, #T_9e71a_row7_col6, #T_9e71a_row8_col3, #T_9e71a_row10_col1, #T_9e71a_row10_col5, #T_9e71a_row10_col9 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_9e71a_row7_col5, #T_9e71a_row10_col0 {
#   background-color: #f5f9fe;
#   color: #000000;
# }
# </style>
# <table id="T_9e71a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9e71a_level0_col0" class="col_heading level0 col0" >mean</th>
#       <th id="T_9e71a_level0_col1" class="col_heading level0 col1" >std</th>
#       <th id="T_9e71a_level0_col2" class="col_heading level0 col2" >min</th>
#       <th id="T_9e71a_level0_col3" class="col_heading level0 col3" >5%</th>
#       <th id="T_9e71a_level0_col4" class="col_heading level0 col4" >25%</th>
#       <th id="T_9e71a_level0_col5" class="col_heading level0 col5" >50%</th>
#       <th id="T_9e71a_level0_col6" class="col_heading level0 col6" >75%</th>
#       <th id="T_9e71a_level0_col7" class="col_heading level0 col7" >90%</th>
#       <th id="T_9e71a_level0_col8" class="col_heading level0 col8" >95%</th>
#       <th id="T_9e71a_level0_col9" class="col_heading level0 col9" >99%</th>
#       <th id="T_9e71a_level0_col10" class="col_heading level0 col10" >max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9e71a_level0_row0" class="row_heading level0 row0" >allelectrons_Total</th>
#       <td id="T_9e71a_row0_col0" class="data row0 col0" >126.46</td>
#       <td id="T_9e71a_row0_col1" class="data row0 col1" >207.56</td>
#       <td id="T_9e71a_row0_col2" class="data row0 col2" >0.00</td>
#       <td id="T_9e71a_row0_col3" class="data row0 col3" >33.00</td>
#       <td id="T_9e71a_row0_col4" class="data row0 col4" >68.00</td>
#       <td id="T_9e71a_row0_col5" class="data row0 col5" >100.00</td>
#       <td id="T_9e71a_row0_col6" class="data row0 col6" >128.00</td>
#       <td id="T_9e71a_row0_col7" class="data row0 col7" >220.00</td>
#       <td id="T_9e71a_row0_col8" class="data row0 col8" >278.00</td>
#       <td id="T_9e71a_row0_col9" class="data row0 col9" >710.00</td>
#       <td id="T_9e71a_row0_col10" class="data row0 col10" >10,116.00</td>
#     </tr>
#     <tr>
#       <th id="T_9e71a_level0_row1" class="row_heading level0 row1" >density_Total</th>
#       <td id="T_9e71a_row1_col0" class="data row1 col0" >14.79</td>
#       <td id="T_9e71a_row1_col1" class="data row1 col1" >18.98</td>
#       <td id="T_9e71a_row1_col2" class="data row1 col2" >0.00</td>
#       <td id="T_9e71a_row1_col3" class="data row1 col3" >2.33</td>
#       <td id="T_9e71a_row1_col4" class="data row1 col4" >7.56</td>
#       <td id="T_9e71a_row1_col5" class="data row1 col5" >10.65</td>
#       <td id="T_9e71a_row1_col6" class="data row1 col6" >16.60</td>
#       <td id="T_9e71a_row1_col7" class="data row1 col7" >27.11</td>
#       <td id="T_9e71a_row1_col8" class="data row1 col8" >37.78</td>
#       <td id="T_9e71a_row1_col9" class="data row1 col9" >105.51</td>
#       <td id="T_9e71a_row1_col10" class="data row1 col10" >643.09</td>
#     </tr>
#     <tr>
#       <th id="T_9e71a_level0_row2" class="row_heading level0 row2" >allelectrons_Average</th>
#       <td id="T_9e71a_row2_col0" class="data row2 col0" >17.41</td>
#       <td id="T_9e71a_row2_col1" class="data row2 col1" >11.00</td>
#       <td id="T_9e71a_row2_col2" class="data row2 col2" >0.00</td>
#       <td id="T_9e71a_row2_col3" class="data row2 col3" >7.50</td>
#       <td id="T_9e71a_row2_col4" class="data row2 col4" >10.00</td>
#       <td id="T_9e71a_row2_col5" class="data row2 col5" >12.67</td>
#       <td id="T_9e71a_row2_col6" class="data row2 col6" >22.00</td>
#       <td id="T_9e71a_row2_col7" class="data row2 col7" >32.00</td>
#       <td id="T_9e71a_row2_col8" class="data row2 col8" >42.80</td>
#       <td id="T_9e71a_row2_col9" class="data row2 col9" >50.00</td>
#       <td id="T_9e71a_row2_col10" class="data row2 col10" >67.00</td>
#     </tr>
#     <tr>
#       <th id="T
# Test information
#
# <class 'pandas.core.frame.DataFrame'>
# Index: 6939 entries, 10407 to 17345
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   allelectrons_Total     6939 non-null   uint16
#  1   density_Total          6939 non-null   float64
#  2   allelectrons_Average   6939 non-null   float64
#  3   val_e_Average          6939 non-null   float64
#  4   atomicweight_Average   6939 non-null   float64
#  5   ionenergy_Average      6939 non-null   float64
#  6   el_neg_chi_Average     6939 non-null   float64
#  7   R_vdw_element_Average  6939 non-null   float64
#  8   R_cov_element_Average  6939 non-null   float64
#  9   zaratio_Average        6939 non-null   float64
#  10  density_Average        6939 non-null   float64
#  11  Source                 6939 non-null   object
# dtypes: float64(10), object(1), uint16(1)
# memory usage: 664.1+ KB
# None
# Original description
# <style type="text/css">
# #T_d9618_row0_col0, #T_d9618_row0_col1, #T_d9618_row0_col3, #T_d9618_row0_col4, #T_d9618_row0_col5, #T_d9618_row0_col6, #T_d9618_row0_col7, #T_d9618_row0_col8, #T_d9618_row0_col9, #T_d9618_row0_col10 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_d9618_row0_col2, #T_d9618_row1_col2, #T_d9618_row2_col2, #T_d9618_row3_col1, #T_d9618_row3_col2, #T_d9618_row3_col10, #T_d9618_row4_col2, #T_d9618_row5_col1, #T_d9618_row5_col2, #T_d9618_row5_col10, #T_d9618_row6_col1, #T_d9618_row6_col2, #T_d9618_row6_col8, #T_d9618_row6_col9, #T_d9618_row6_col10, #T_d9618_row7_col0, #T_d9618_row7_col1, #T_d9618_row7_col2, #T_d9618_row7_col6, #T_d9618_row7_col7, #T_d9618_row7_col8, #T_d9618_row7_col9, #T_d9618_row7_col10, #T_d9618_row8_col0, #T_d9618_row8_col1, #T_d9618_row8_col2, #T_d9618_row8_col4, #T_d9618_row8_col5, #T_d9618_row8_col6, #T_d9618_row8_col7, #T_d9618_row8_col8, #T_d9618_row8_col9, #T_d9618_row8_col10, #T_d9618_row9_col0, #T_d9618_row9_col1, #T_d9618_row9_col2, #T_d9618_row9_col3, #T_d9618_row9_col4, #T_d9618_row9_col5, #T_d9618_row9_col6, #T_d9618_row9_col7, #T_d9618_row9_col8, #T_d9618_row9_col9, #T_d9618_row9_col10, #T_d9618_row10_col1, #T_d9618_row10_col2, #T_d9618_row10_col3, #T_d9618_row10_col4, #T_d9618_row10_col5, #T_d9618_row10_col10 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_d9618_row1_col0, #T_d9618_row1_col6 {
#   background-color: #e6f0f9;
#   color: #000000;
# }
# #T_d9618_row1_col1, #T_d9618_row2_col0, #T_d9618_row2_col6, #T_d9618_row6_col3 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_d9618_row1_col3 {
#   background-color: #e7f1fa;
#   color: #000000;
# }
# #T_d9618_row1_col4, #T_d9618_row4_col0 {
#   background-color: #e3eef8;
#   color: #000000;
# }
# #T_d9618_row1_col5, #T_d9618_row5_col4 {
#   background-color: #e2edf8;
#   color: #000000;
# }
# #T_d9618_row1_col7 {
#   background-color: #e4eff9;
#   color: #000000;
# }
# #T_d9618_row1_col8 {
#   background-color: #e1edf8;
#   color: #000000;
# }
# #T_d9618_row1_col9, #T_d9618_row4_col5 {
#   background-color: #e0ecf8;
#   color: #000000;
# }
# #T_d9618_row1_col10 {
#   background-color: #eff6fc;
#   color: #000000;
# }
# #T_d9618_row2_col1, #T_d9618_row3_col6, #T_d9618_row3_col7, #T_d9618_row3_col8, #T_d9618_row4_col10, #T_d9618_row5_col9, #T_d9618_row7_col4, #T_d9618_row10_col7, #T_d9618_row10_col8 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_d9618_row2_col3 {
#   background-color: #d9e8f5;
#   color: #000000;
# }
# #T_d9618_row2_col4, #T_d9618_row4_col9 {
#   background-color: #e5eff9;
#   color: #000000;
# }
# #T_d9618_row2_col5, #T_d9618_row5_col5 {
#   background-color: #ecf4fb;
#   color: #000000;
# }
# #T_d9618_row2_col7 {
#   background-color: #edf4fc;
#   color: #000000;
# }
# #T_d9618_row2_col8 {
#   background-color: #ebf3fb;
#   color: #000000;
# }
# #T_d9618_row2_col9, #T_d9618_row3_col4 {
#   background-color: #f0f6fd;
#   color: #000000;
# }
# #T_d9618_row2_col10, #T_d9618_row3_col9, #T_d9618_row6_col0, #T_d9618_row6_col6, #T_d9618_row6_col7, #T_d9618_row7_col5, #T_d9618_row8_col3, #T_d9618_row10_col0, #T_d9618_row10_col6, #T_d9618_row10_col9 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_d9618_row3_col0, #T_d9618_row6_col5 {
#   background-color: #f5f9fe;
#   color: #000000;
# }
# #T_d9618_row3_col3 {
#   background-color: #e8f1fa;
#   color: #000000;
# }
# #T_d9618_row3_col5, #T_d9618_row5_col7, #T_d9618_row5_col8, #T_d9618_row6_col4 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_d9618_row4_col1, #T_d9618_row5_col6 {
#   background-color: #f2f7fd;
#   color: #000000;
# }
# #T_d9618_row4_col3 {
#   background-color: #b5d4e9;
#   color: #000000;
# }
# #T_d9618_row4_col4 {
#   background-color: #d2e3f3;
#   color: #000000;
# }
# #T_d9618_row4_col6 {
#   background-color: #e3eef9;
#   color: #000000;
# }
# #T_d9618_row4_col7 {
#   background-color: #dfebf7;
#   color: #000000;
# }
# #T_d9618_row4_col8 {
#   background-color: #dce9f6;
#   color: #000000;
# }
# #T_d9618_row5_col0 {
#   background-color: #f1f7fd;
#   color: #000000;
# }
# #T_d9618_row5_col3 {
#   background-color: #ccdff1;
#   color: #000000;
# }
# #T_d9618_row7_col3 {
#   background-color: #f2f8fd;
#   color: #000000;
# }
# </style>
# <table id="T_d9618">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d9618_level0_col0" class="col_heading level0 col0" >mean</th>
#       <th id="T_d9618_level0_col1" class="col_heading level0 col1" >std</th>
#       <th id="T_d9618_level0_col2" class="col_heading level0 col2" >min</th>
#       <th id="T_d9618_level0_col3" class="col_heading level0 col3" >5%</th>
#       <th id="T_d9618_level0_col4" class="col_heading level0 col4" >25%</th>
#       <th id="T_d9618_level0_col5" class="col_heading level0 col5" >50%</th>
#       <th id="T_d9618_level0_col6" class="col_heading level0 col6" >75%</th>
#       <th id="T_d9618_level0_col7" class="col_heading level0 col7" >90%</th>
#       <th id="T_d9618_level0_col8" class="col_heading level0 col8" >95%</th>
#       <th id="T_d9618_level0_col9" class="col_heading level0 col9" >99%</th>
#       <th id="T_d9618_level0_col10" class="col_heading level0 col10" >max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d9618_level0_row0" class="row_heading level0 row0" >allelectrons_Total</th>
#       <td id="T_d9618_row0_col0" class="data row0 col0" >312.86</td>
#       <td id="T_d9618_row0_col1" class="data row0 col1" >853.33</td>
#       <td id="T_d9618_row0_col2" class="data row0 col2" >0.00</td>
#       <td id="T_d9618_row0_col3" class="data row0 col3" >39.05</td>
#       <td id="T_d9618_row0_col4" class="data row0 col4" >98.25</td>
#       <td id="T_d9618_row0_col5" class="data row0 col5" >186.50</td>
#       <td id="T_d9618_row0_col6" class="data row0 col6" >390.00</td>
#       <td id="T_d9618_row0_col7" class="data row0 col7" >530.80</td>
#       <td id="T_d9618_row0_col8" class="data row0 col8" >600.95</td>
#       <td id="T_d9618_row0_col9" class="data row0 col9" >1,256.44</td>
#       <td id="T_d9618_row0_col10" class="data row0 col10" >15,300.00</td>
#     </tr>
#     <tr>
#       <th id="T_d9618_level0_row1" class="row_heading level0 row1" >density_Total</th>
#       <td id="T_d9618_row1_col0" class="data row1 col0" >27.86</td>
#       <td id="T_d9618_row1_col1" class="data row1 col1" >39.24</td>
#       <td id="T_d9618_row1_col2" class="data row1 col2" >0.00</td>
#       <td id="T_d9618_row1_col3" class="data row1 col3" >3.55</td>
#       <td id="T_d9618_row1_col4" class="data row1 col4" >10.56</td>
#       <td id="T_d9618_row1_col5" class="data row1 col5" >20.74</td>
#       <td id="T_d9618_row1_col6" class="data row1 col6" >34.82</td>
#       <td id="T_d9618_row1_col7" class="data row1 col7" >51.86</td>
#       <td id="T_d9618_row1_col8" class="data row1 col8" >68.29</td>
#       <td id="T_d9618_row1_col9" class="data row1 col9" >143.11</td>
#       <td id="T_d9618_row1_col10" class="data row1 col10" >643.09</td>
#     </tr>
#     <tr>
#       <th id="T_d9618_level0_row2" class="row_heading level0 row2" >allelectrons_Average</th>
#       <td id="T_d9618_row2_col0" class="data row2 col0" >14.81</td>
#       <td id="T_d9618_row2_col1" class="data row2 col1" >9.96</td>
#       <td id="T_d9618_row2_col2" class="data row2 col2" >0.00</td>
#       <td id="T_d9618_row2_col3" class="data row2 col3" >6.25</td>
#       <td id="T_d9618_row2_col4" class="data row2 col4" >9.37</td>
#       <td id="T_d9618_row2_col5" class="data row2 col5" >10.85</td>
#       <td id="T_d9618_row2_col6" class="data row2 col6" >17.42</td>
#       <td id="T_d9618_row2_col7" class="data row2 col7" >28.17</td>
#       <td id="T_d9618_row2_col8" class="data row2 col8" >36.00</td>
#       <td id="T_d9618_row2_col9" class="data row2 col9" >49.79</td>
#       <td id="T_d9618_row2_col10" class="data row2 col10" >67.00</td>
#     </tr>
#     <tr>
#       <th id="T_d9618_level0_row3" class="row_heading level0 row3" >val_e_Average</th>
#       <td id="T_d9618_row3_col0" class="data row3 col0" >4.42</td>
#       <td id="T_d9618_row3_col1" class="data row3 col1" >0.81</td>
#       <td id="T_d9618_row3_col2" class="data row3 col2" >0.00</td>
#       <td id="T_d9618_row3_col3" class="data row3 col3" >3.26</td>
#       <td id="T_d9618_row3_col4" class="data row3 col4" >4.
# Original information
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 622 entries, 17346 to 17967
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   allelectrons_Total     622 non-null    uint16
#  1   density_Total          622 non-null    float64
#  2   allelectrons_Average   622 non-null    float64
#  3   val_e_Average          622 non-null    float64
#  4   atomicweight_Average   622 non-null    float64
#  5   ionenergy_Average      622 non-null    float64
#  6   el_neg_chi_Average     622 non-null    float64
#  7   R_vdw_element_Average  622 non-null    float64
#  8   R_cov_element_Average  622 non-null    float64
#  9   zaratio_Average        622 non-null    float64
#  10  density_Average        622 non-null    float64
#  11  Hardness               622 non-null    float64
#  12  Source                 622 non-null    object
# dtypes: float64(11), object(1), uint16(1)
# memory usage: 59.7+ KB
# None
# Unique and null values
# <style type="text/css">
# #T_b3bfd_row0_col0 {
#   background-color: #bfd8ed;
#   color: #000000;
# }
# #T_b3bfd_row0_col1, #T_b3bfd_row1_col1, #T_b3bfd_row2_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_b3bfd_row0_col2 {
#   background-color: #539ecd;
#   color: #f1f1f1;
# }
# #T_b3bfd_row0_col3 {
#   background-color: #d3e3f3;
#   color: #000000;
# }
# #T_b3bfd_row0_col4, #T_b3bfd_row1_col5 {
#   background-color: #1c6bb0;
#   color: #f1f1f1;
# }
# #T_b3bfd_row0_col5 {
#   background-color: #135fa7;
#   color: #f1f1f1;
# }
# #T_b3bfd_row0_col6 {
#   background-color: #3484bf;
#   color: #f1f1f1;
# }
# #T_b3bfd_row0_col7 {
#   background-color: #3686c0;
#   color: #f1f1f1;
# }
# #T_b3bfd_row0_col8 {
#   background-color: #3f8fc5;
#   color: #f1f1f1;
# }
# #T_b3bfd_row0_col9 {
#   background-color: #2373b6;
#   color: #f1f1f1;
# }
# #T_b3bfd_row0_col10 {
#   background-color: #5ca4d0;
#   color: #f1f1f1;
# }
# #T_b3bfd_row0_col11, #T_b3bfd_row1_col11, #T_b3bfd_row2_col11, #T_b3bfd_row3_col0, #T_b3bfd_row3_col1, #T_b3bfd_row3_col2, #T_b3bfd_row3_col3, #T_b3bfd_row3_col4, #T_b3bfd_row3_col5, #T_b3bfd_row3_col6, #T_b3bfd_row3_col7, #T_b3bfd_row3_col8, #T_b3bfd_row3_col9, #T_b3bfd_row3_col10, #T_b3bfd_row3_col11, #T_b3bfd_row4_col0, #T_b3bfd_row4_col1, #T_b3bfd_row4_col2, #T_b3bfd_row4_col3, #T_b3bfd_row4_col4, #T_b3bfd_row4_col5, #T_b3bfd_row4_col6, #T_b3bfd_row4_col7, #T_b3bfd_row4_col8, #T_b3bfd_row4_col9, #T_b3bfd_row4_col10, #T_b3bfd_row4_col11, #T_b3bfd_row5_col0, #T_b3bfd_row5_col1, #T_b3bfd_row5_col2, #T_b3bfd_row5_col3, #T_b3bfd_row5_col4, #T_b3bfd_row5_col5, #T_b3bfd_row5_col6, #T_b3bfd_row5_col7, #T_b3bfd_row5_col8, #T_b3bfd_row5_col9, #T_b3bfd_row5_col10, #T_b3bfd_row5_col11 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_b3bfd_row1_col0 {
#   background-color: #bdd7ec;
#   color: #000000;
# }
# #T_b3bfd_row1_col2 {
#   background-color: #549fcd;
#   color: #f1f1f1;
# }
# #T_b3bfd_row1_col3 {
#   background-color: #cfe1f2;
#   color: #000000;
# }
# #T_b3bfd_row1_col4 {
#   background-color: #1562a9;
#   color: #f1f1f1;
# }
# #T_b3bfd_row1_col6 {
#   background-color: #2b7bba;
#   color: #f1f1f1;
# }
# #T_b3bfd_row1_col7 {
#   background-color: #3181bd;
#   color: #f1f1f1;
# }
# #T_b3bfd_row1_col8 {
#   background-color: #3a8ac2;
#   color: #f1f1f1;
# }
# #T_b3bfd_row1_col9 {
#   background-color: #2676b8;
#   color: #f1f1f1;
# }
# #T_b3bfd_row1_col10 {
#   background-color: #3888c1;
#   color: #f1f1f1;
# }
# #T_b3bfd_row2_col0 {
#   background-color: #5ba3d0;
#   color: #f1f1f1;
# }
# #T_b3bfd_row2_col2 {
#   background-color: #1b69af;
#   color: #f1f1f1;
# }
# #T_b3bfd_row2_col3 {
#   background-color: #aed1e7;
#   color: #000000;
# }
# #T_b3bfd_row2_col4, #T_b3bfd_row2_col5 {
#   background-color: #083370;
#   color: #f1f1f1;
# }
# #T_b3bfd_row2_col6 {
#   background-color: #08478d;
#   color: #f1f1f1;
# }
# #T_b3bfd_row2_col7 {
#   background-color: #084a91;
#   color: #f1f1f1;
# }
# #T_b3bfd_row2_col8 {
#   background-color: #105ba4;
#   color: #f1f1f1;
# }
# #T_b3bfd_row2_col9, #T_b3bfd_row2_col10 {
#   background-color: #08326e;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_b3bfd">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b3bfd_level0_col0" class="col_heading level0 col0" >allelectrons_Total</th>
#       <th id="T_b3bfd_level0_col1" class="col_heading level0 col1" >density_Total</th>
#       <th id="T_b3bfd_level0_col2" class="col_heading level0 col2" >allelectrons_Average</th>
#       <th id="T_b3bfd_level0_col3" class="col_heading level0 col3" >val_e_Average</th>
#       <th id="T_b3bfd_level0_col4" class="col_heading level0 col4" >atomicweight_Average</th>
#       <th id="T_b3bfd_level0_col5" class="col_heading level0 col5" >ionenergy_Average</th>
#       <th id="T_b3bfd_level0_col6" class="col_heading level0 col6" >el_neg_chi_Average</th>
#       <th id="T_b3bfd_level0_col7" class="col_heading level0 col7" >R_vdw_element_Average</th>
#       <th id="T_b3bfd_level0_col8" class="col_heading level0 col8" >R_cov_element_Average</th>
#       <th id="T_b3bfd_level0_col9" class="col_heading level0 col9" >zaratio_Average</th>
#       <th id="T_b3bfd_level0_col10" class="col_heading level0 col10" >density_Average</th>
#       <th id="T_b3bfd_level0_col11" class="col_heading level0 col11" >Source</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b3bfd_level0_row0" class="row_heading level0 row0" >Train_Nunq</th>
#       <td id="T_b3bfd_row0_col0" class="data row0 col0" >301</td>
#       <td id="T_b3bfd_row0_col1" class="data row0 col1" >1,099</td>
#       <td id="T_b3bfd_row0_col2" class="data row0 col2" >629</td>
#       <td id="T_b3bfd_row0_col3" class="data row0 col3" >205</td>
#       <td id="T_b3bfd_row0_col4" class="data row0 col4" >849</td>
#       <td id="T_b3bfd_row0_col5" class="data row0 col5" >898</td>
#       <td id="T_b3bfd_row0_col6" class="data row0 col6" >745</td>
#       <td id="T_b3bfd_row0_col7" class="data row0 col7" >737</td>
#       <td id="T_b3bfd_row0_col8" class="data row0 col8" >698</td>
#       <td id="T_b3bfd_row0_col9" class="data row0 col9" >815</td>
#       <td id="T_b3bfd_row0_col10" class="data row0 col10" >599</td>
#       <td id="T_b3bfd_row0_col11" class="data row0 col11" >1</td>
#     </tr>
#     <tr>
#       <th id="T_b3bfd_level0_row1" class="row_heading level0 row1" >Test_Nunq</th>
#       <td id="T_b3bfd_row1_col0" class="data row1 col0" >253</td>
#       <td id="T_b3bfd_row1_col1" class="data row1 col1" >904</td>
#       <td id="T_b3bfd_row1_col2" class="data row1 col2" >514</td>
#       <td id="T_b3bfd_row1_col3" class="data row1 col3" >185</td>
#       <td id="T_b3bfd_row1_col4" class="data row1 col4" >728</td>
#       <td id="T_b3bfd_row1_col5" class="data row1 col5" >699</td>
#       <td id="T_b3bfd_row1_col6" class="data row1 col6" >643</td>
#       <td id="T_b3bfd_row1_col7" class="data row1 col7" >622</td>
#       <td id="T_b3bfd_row1_col8" class="data row1 col8" >592</td>
#       <td id="T_b3bfd_row1_col9" class="data row1 col9" >660</td>
#       <td id="T_b3bfd_row1_col10" class="data row1 col10" >598</td>
#       <td id="T_b3bfd_row1_col11" class="data row1 col11" >1</td>
#     </tr>
#     <tr>
#       <th id="T_b3bfd_level0_row2" class="row_heading level0 row2" >Original_Nunq</th>
#       <td id="T_b3bfd_row2_col0" class="data row2 col0" >308</td>
#       <td id="T_b3bfd_row2_col1" class="data row2 col1" >560</td>
#       <td id="T_b3bfd_row2_col2" class="data row2 col2" >436</td>
#       <td id="T_b3bfd_row2_col3" class="data row2 col3" >183</td>
#       <td id="T_b3bfd_row2_col4" class="data row2 col4" >553</td>
#       <td id="T_b3bfd_row2_col5" class="data row2 col5" >552</td>
#       <td id="T_b3bfd_row2_col6" class="data row2 col6" >510</td>
#       <td id="T_b3bfd_row2_col7" class="data row2 col7" >505</td>
#       <td id="T_b3bfd_row2_col8" class="data row2 col8" >467</td>
#       <td id="T_b3bfd_row2_col9" class="data row2 col9" >554</td>
#       <td id="T_b3bfd_row2_col10" class="data row2 col10" >554</td>
#       <td id="T_b3bfd_row2_col11" class="data row2 col11" >1</td>
#     </tr>
#     <tr>
#       <th id="T_b3bfd_level0_row3" class="row_heading level0 row3" >Train_Nulls</th>
#       <td id="T_b3bfd_row3_col0" class="data row3 col0" >0</td>
#       <td id="T_b3bfd_row3_col1" class="data row3 col1" >0</td>
#       <td id="T_b3bfd_row3_col2" class="data row3 col2" >0</td>
#       <td id="T_b3bfd_row3_col3" class="data row3 col3" >0</td>
#       <td id="T_b3bfd_row3_col4" class="data row3 col4" >0</td>
#       <td id="T_b3bfd_row3_col5" class="data row3 col5" >0</td>
#       <td id="T_b3bfd_row3_col6" class="data row3 col6" >0</td>
#       <td id="T_b3bfd_row3_col7" class="data row3 col7" >0</td>
#       <td id="T_b3bfd_row3_col8" class="data row3 col8" >0</td>
#       <td id="T_b3bfd_row3_col9" class="data row3 col9" >0</td>
#       <td id="T_b3bfd_row3_col10" class="data row3 col10" >0</td>
#       <td id="T_b3bfd_row3_col11" class="data row3 col11" >0</td>
#     </tr>
#     <tr>
#       <th id="T_b3bfd_level0_row4" class="row_heading level0 row4" >Test_Nulls</th>
#       <td id="T_b3bfd_row4_col0" class="data row4 col0" >0</td>
#       <td id="T_b3bfd_row4_col1" class="data row4 col1" >0</td>
#       <td id="T_b3bfd_row4_col2" class="data row4 col2" >0</td>
# CPU times: user 941 ms, sys: 18.5 ms, total: 959 ms
# Wall time: 1.03 s

# %% [markdown]
# ## <div style= "font-family: Cambria; font-weight:bold; letter-spacing: 0px; color:#ffffff; font-size:120%; text-align:left;padding:3.0px; background: #0059b3; border-bottom: 8px solid #e6e6e6" > INFERENCES<br> <div>

# %% [markdown]
# <div style= "font-family: Cambria; letter-spacing: 0px; color:#000000; font-size:110%; text-align:left;padding:3.0px; background: #f2f2f2" >
# 1. We have numerical columns<br>
# 2. Original dataset has no nulls.<br>
# 3. The dataset is quite small, so building a CV is difficult- luck will play a huge part in this challenge<br>
# </div>

# %% [markdown]
# <a id="4"></a>
# # <div style= "font-family: Cambria; font-weight:bold; letter-spacing: 0px; color:black; font-size:120%; text-align:left;padding:3.0px; background: #cceeff; border-bottom: 8px solid #004466" > ADVERSARIAL CV<br><div>

# %%
# %%time

# Performing adversarial CV between the 2 specified datasets:-
def Do_AdvCV(df1:pd.DataFrame, df2:pd.DataFrame, source1:str, source2:str):
    "This function performs an adversarial CV between the 2 provided datasets if needed by the user";
    
    # Adversarial CV per column:-
    ftre = pp.test.select_dtypes(include = np.number).\
    drop(columns = ['id', "Source"], errors = 'ignore').columns;
    adv_cv = {};

    for col in ftre:
        shuffle_state = np.random.randint(low = 10, high = 100, size= 1);

        full_df = \
        pd.concat([df1[[col]].assign(Source = source1), df2[[col]].assign(Source = source2)], 
                  axis=0, ignore_index = True).\
        sample(frac = 1.00, random_state = shuffle_state);

        full_df = full_df.assign(Source_Nb = full_df['Source'].eq(source2).astype(np.int8));

        # Checking for adversarial CV:-
        model = LGBMClassifier(random_state = CFG.state, max_depth = 6, learning_rate = 0.05);
        cv    = all_cv['SKF'];
        score = np.mean(cross_val_score(model, 
                                        full_df[[col]], 
                                        full_df.Source_Nb, 
                                        scoring= 'roc_auc', 
                                        cv     = cv)
                       );
        adv_cv.update({col: round(score, 4)});
        collect();
    
    del ftre;
    collect();
    
    fig, ax = plt.subplots(1,1,figsize = (12, 5));
    pd.Series(adv_cv).plot.bar(color = 'tab:blue', ax = ax);
    ax.axhline(y = 0.60, color = 'red', linewidth = 2.75);
    ax.grid(**CFG.grid_specs); 
    plt.yticks(np.arange(0.0, 0.81, 0.05));
    plt.show();
    
# Implementing the adversarial CV:-
if CFG.adv_cv_req == "Y":
    PrintColor(f"\n---------- Adversarial CV - Train vs Original ----------\n", 
               color = Fore.MAGENTA);
    Do_AdvCV(df1 = pp.train, df2 = pp.original, source1 = 'Train', source2 = 'Original');
    
    PrintColor(f"\n---------- Adversarial CV - Train vs Test ----------\n", 
               color = Fore.MAGENTA);
    Do_AdvCV(df1 = pp.train, df2 = pp.test, source1 = 'Train', source2 = 'Test');
    
    PrintColor(f"\n---------- Adversarial CV - Original vs Test ----------\n", 
               color = Fore.MAGENTA);
    Do_AdvCV(df1 = pp.original, df2 = pp.test, source1 = 'Original', source2 = 'Test');   
    
if CFG.adv_cv_req == "N":
    PrintColor(f"\nAdversarial CV is not needed\n", color = Fore.RED);
    
collect();
print();
# Out:
# Adversarial CV is not needed
#
#
# CPU times: user 134 ms, sys: 397 µs, total: 135 ms
# Wall time: 134 ms

# %%
# %%time 

print();
train, test, strt_ftre = pp.ConjoinTrainOrig(), pp.test.copy(deep = True), deepcopy(pp.strt_ftre);
cat_cols  = [];
cont_cols = [col for col in pp.strt_ftre if col not in cat_cols + [CFG.target, "Source"]];

if CFG.drop_nulls == "Y":
    train = train.dropna();
else: 
    pass;

PrintColor(f"\nCategory columns\n");
display(cat_cols);
PrintColor(f"\nContinuous columns\n");
display(np.array(cont_cols));
PrintColor(f"\nAll columns\n");
display(strt_ftre);

print();
collect();
# Out:
# Train shape before conjoining with original = (10407, 13)
# Train shape after conjoining with original= (11029, 13)
# Train shape after de-duping = (11006, 13)
#
# Category columns
# []
# Continuous columns
# array(['allelectrons_Total', 'density_Total', 'allelectrons_Average',
#        'val_e_Average', 'atomicweight_Average', 'ionenergy_Average',
#        'el_neg_chi_Average', 'R_vdw_element_Average',
#        'R_cov_element_Average', 'zaratio_Average', 'density_Average'],
#       dtype='<U21')
# All columns
# Index(['allelectrons_Total', 'density_Total', 'allelectrons_Average',
#        'val_e_Average', 'atomicweight_Average', 'ionenergy_Average',
#        'el_neg_chi_Average', 'R_vdw_element_Average', 'R_cov_element_Average',
#        'zaratio_Average', 'density_Average', 'Source'],
#       dtype='object')
# CPU times: user 153 ms, sys: 5.72 ms, total: 158 ms
# Wall time: 158 ms

# %% [markdown]
# ## <div style= "font-family: Cambria; font-weight:bold; letter-spacing: 0px; color:#ffffff; font-size:120%; text-align:left;padding:3.0px; background: #0059b3; border-bottom: 8px solid #e6e6e6" > INFERENCES<br><div>

# %% [markdown]
# <div style= "font-family: Cambria; letter-spacing: 0px; color:#000000; font-size:110%; text-align:left;padding:3.0px; background: #f2f2f2" >
# 1. Train-test belong to the same distribution, we can perhaps rely on the CV score<br>
# 2. We need to further check the train-original distribution further, adversarial validation results indicate that we cannot use the original dataset based on a couple of features<br>
# </div>

# %% [markdown]
# <a id="5"></a>
# # <div style= "font-family: Cambria; font-weight:bold; letter-spacing: 0px; color:black; font-size:120%; text-align:left;padding:3.0px; background: #cceeff; border-bottom: 8px solid #004466" > VISUALS AND EDA <br><div>

# %% [markdown]
# <a id="5.2"></a>
# ## <div style= "font-family: Cambria; font-weight:bold; letter-spacing: 0px; color:#ffffff; font-size:120%; text-align:left;padding:3.0px; background: #0059b3; border-bottom: 8px solid #e6e6e6" > TARGET PLOT<br><div>

# %%
# %%time 

if CFG.ftre_plots_req == "Y":
    fig, axes = plt.subplots(1,2, figsize = (20, 5), sharey = True, gridspec_kw = {'wspace': 0.35});
    
    for i, df in tqdm(enumerate([pp.train, pp.original]), "Target plot ---> "):
        ax= axes[i];
        a = df[CFG.target].value_counts(normalize = True);
        a.sort_index().plot.bar(color = '#3377ff', ax = ax);
        df_name = 'Train' if i == 0 else "Original";
        _ = ax.set_title(f"\n{df_name} data\n", **CFG.title_specs);
        
    plt.tight_layout();
    plt.show();
    
print();
collect();
# Out:
# CPU times: user 135 ms, sys: 0 ns, total: 135 ms
# Wall time: 134 ms

# %% [markdown]
# <a id="5.5"></a>
# ## <div style= "font-family: Cambria; font-weight:bold; letter-spacing: 0px; color:#ffffff; font-size:120%; text-align:left;padding:3.0px; background: #0059b3; border-bottom: 8px solid #e6e6e6" > CONTINUOUS COLUMN PLOTS<br><div>

# %%
# %%time 

if CFG.ftre_plots_req == "Y":
    df = pd.concat([pp.train[cont_cols].assign(Source = 'Train'), 
                    pp.test[cont_cols].assign(Source = 'Test'),
                    pp.original[cont_cols].assign(Source = "Original")
                   ], 
                   axis=0, ignore_index = True
                  );
    
    fig, axes = plt.subplots(len(cont_cols), 4 ,figsize = (16, len(cont_cols) * 4.2), 
                             gridspec_kw = {'hspace': 0.35, 'wspace': 0.3, 'width_ratios': [0.80, 0.20, 0.20, 0.20]});
    
    for i,col in enumerate(cont_cols):
        ax = axes[i,0];
        sns.kdeplot(data = df[[col, 'Source']], x = col, hue = 'Source', 
                    palette = ['#0039e6', '#ff5500', '#00b300'], 
                    ax = ax, linewidth = 2.1
                   );
        ax.set_title(f"\n{col}", **CFG.title_specs);
        ax.grid(**CFG.grid_specs);
        ax.set(xlabel = '', ylabel = '');
        
        ax = axes[i,1];
        sns.boxplot(data = df.loc[df.Source == 'Train', [col]], y = col, width = 0.25,
                    color = '#33ccff', saturation = 0.90, linewidth = 0.90, 
                    fliersize= 2.25,
                    ax = ax);
        ax.set(xlabel = '', ylabel = '');
        ax.set_title(f"Train", **CFG.title_specs);
        
        ax = axes[i,2];
        sns.boxplot(data = df.loc[df.Source == 'Test', [col]], y = col, width = 0.25, fliersize= 2.25,
                    color = '#80ffff', saturation = 0.6, linewidth = 0.90, 
                    ax = ax); 
        ax.set(xlabel = '', ylabel = '');
        ax.set_title(f"Test", **CFG.title_specs);
        
        ax = axes[i,3];
        sns.boxplot(data = df.loc[df.Source == 'Original', [col]], y = col, width = 0.25, fliersize= 2.25,
                    color = '#99ddff', saturation = 0.6, linewidth = 0.90, 
                    ax = ax); 
        ax.set(xlabel = '', ylabel = '');
        ax.set_title(f"Original", **CFG.title_specs);
              
    plt.suptitle(f"\nDistribution analysis- continuous columns\n", **CFG.title_specs, 
                 y = 0.905, x = 0.50
                );
    plt.tight_layout();
    plt.show();
    
print();
collect();
# Out:
# CPU times: user 137 ms, sys: 0 ns, total: 137 ms
# Wall time: 136 ms

# %%
# %%time 

# Calculating skewness across columns:-
skew_df = pd.DataFrame(index = strt_ftre[0:-1]);
for col, df in {"Train": pp.train, "Test": pp.test, "Original": pp.original}.items():
    skew_df = \
    pd.concat([skew_df, 
               df.drop(columns = [CFG.target, "Source", "id"], errors = "ignore").skew()],
              axis=1).rename({0: col}, axis=1);

PrintColor(f"\nSkewness across independent features\n");
display(skew_df.transpose().style.format(precision = 2).background_gradient("Pastel2"));

del skew_df;
collect();
print();
# Out:
# Skewness across independent features
# <style type="text/css">
# #T_02564_row0_col0, #T_02564_row0_col9, #T_02564_row1_col1, #T_02564_row1_col3, #T_02564_row1_col5, #T_02564_row1_col6, #T_02564_row1_col8, #T_02564_row2_col2, #T_02564_row2_col4, #T_02564_row2_col7, #T_02564_row2_col10 {
#   background-color: #cccccc;
#   color: #000000;
# }
# #T_02564_row0_col1, #T_02564_row0_col2, #T_02564_row0_col4, #T_02564_row0_col7, #T_02564_row1_col2, #T_02564_row1_col4, #T_02564_row1_col10, #T_02564_row2_col0, #T_02564_row2_col1, #T_02564_row2_col3, #T_02564_row2_col5, #T_02564_row2_col6, #T_02564_row2_col8, #T_02564_row2_col9 {
#   background-color: #b3e2cd;
#   color: #000000;
# }
# #T_02564_row0_col3, #T_02564_row0_col5 {
#   background-color: #fff2ae;
#   color: #000000;
# }
# #T_02564_row0_col6, #T_02564_row0_col8, #T_02564_row1_col0 {
#   background-color: #f1e2cc;
#   color: #000000;
# }
# #T_02564_row0_col10 {
#   background-color: #fdcdac;
#   color: #000000;
# }
# #T_02564_row1_col7, #T_02564_row1_col9 {
#   background-color: #cbd5e8;
#   color: #000000;
# }
# </style>
# <table id="T_02564">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_02564_level0_col0" class="col_heading level0 col0" >allelectrons_Total</th>
#       <th id="T_02564_level0_col1" class="col_heading level0 col1" >density_Total</th>
#       <th id="T_02564_level0_col2" class="col_heading level0 col2" >allelectrons_Average</th>
#       <th id="T_02564_level0_col3" class="col_heading level0 col3" >val_e_Average</th>
#       <th id="T_02564_level0_col4" class="col_heading level0 col4" >atomicweight_Average</th>
#       <th id="T_02564_level0_col5" class="col_heading level0 col5" >ionenergy_Average</th>
#       <th id="T_02564_level0_col6" class="col_heading level0 col6" >el_neg_chi_Average</th>
#       <th id="T_02564_level0_col7" class="col_heading level0 col7" >R_vdw_element_Average</th>
#       <th id="T_02564_level0_col8" class="col_heading level0 col8" >R_cov_element_Average</th>
#       <th id="T_02564_level0_col9" class="col_heading level0 col9" >zaratio_Average</th>
#       <th id="T_02564_level0_col10" class="col_heading level0 col10" >density_Average</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_02564_level0_row0" class="row_heading level0 row0" >Train</th>
#       <td id="T_02564_row0_col0" class="data row0 col0" >39.93</td>
#       <td id="T_02564_row0_col1" class="data row0 col1" >9.76</td>
#       <td id="T_02564_row0_col2" class="data row0 col2" >1.66</td>
#       <td id="T_02564_row0_col3" class="data row0 col3" >-2.35</td>
#       <td id="T_02564_row0_col4" class="data row0 col4" >1.80</td>
#       <td id="T_02564_row0_col5" class="data row0 col5" >-3.55</td>
#       <td id="T_02564_row0_col6" class="data row0 col6" >-3.47</td>
#       <td id="T_02564_row0_col7" class="data row0 col7" >-4.67</td>
#       <td id="T_02564_row0_col8" class="data row0 col8" >-0.54</td>
#       <td id="T_02564_row0_col9" class="data row0 col9" >-1.32</td>
#       <td id="T_02564_row0_col10" class="data row0 col10" >1.66</td>
#     </tr>
#     <tr>
#       <th id="T_02564_level0_row1" class="row_heading level0 row1" >Test</th>
#       <td id="T_02564_row1_col0" class="data row1 col0" >33.39</td>
#       <td id="T_02564_row1_col1" class="data row1 col1" >12.68</td>
#       <td id="T_02564_row1_col2" class="data row1 col2" >1.68</td>
#       <td id="T_02564_row1_col3" class="data row1 col3" >-2.13</td>
#       <td id="T_02564_row1_col4" class="data row1 col4" >1.81</td>
#       <td id="T_02564_row1_col5" class="data row1 col5" >-3.31</td>
#       <td id="T_02564_row1_col6" class="data row1 col6" >-3.22</td>
#       <td id="T_02564_row1_col7" class="data row1 col7" >-4.59</td>
#       <td id="T_02564_row1_col8" class="data row1 col8" >-0.48</td>
#       <td id="T_02564_row1_col9" class="data row1 col9" >-1.66</td>
#       <td id="T_02564_row1_col10" class="data row1 col10" >1.61</td>
#     </tr>
#     <tr>
#       <th id="T_02564_level0_row2" class="row_heading level0 row2" >Original</th>
#       <td id="T_02564_row2_col0" class="data row2 col0" >13.55</td>
#       <td id="T_02564_row2_col1" class="data row2 col1" >9.67</td>
#       <td id="T_02564_row2_col2" class="data row2 col2" >2.02</td>
#       <td id="T_02564_row2_col3" class="data row2 col3" >-2.72</td>
#       <td id="T_02564_row2_col4" class="data row2 col4" >2.17</td>
#       <td id="T_02564_row2_col5" class="data row2 col5" >-4.20</td>
#       <td id="T_02564_row2_col6" class="data row2 col6" >-4.58</td>
#       <td id="T_02564_row2_col7" class="data row2 col7" >-4.36</td>
#       <td id="T_02564_row2_col8" class="data row2 col8" >-0.94</td>
#       <td id="T_02564_row2_col9" class="data row2 col9" >-1.86</td>
#       <td id="T_02564_row2_col10" class="data row2 col10" >1.80</td>
#     </tr>
#   </tbody>
# </table>
# CPU times: user 167 ms, sys: 1.41 ms, total: 168 ms
# Wall time: 167 ms

# %% [markdown]
# <a id="5.6"></a>
# ## <div style= "font-family: Cambria; font-weight:bold; letter-spacing: 0px; color:#ffffff; font-size:120%; text-align:left;padding:3.0px; background: #0059b3; border-bottom: 8px solid #e6e6e6" > CATEGORY COLUMN PLOTS<br><div>

# %%
# %%time 

if CFG.ftre_plots_req == "Y" and cat_cols != []:
    fig, axes = plt.subplots(len(cat_cols), 3, figsize = (20, len(cat_cols)* 4.5), 
                             gridspec_kw = {'wspace': 0.25, 'hspace': 0.3});

    for i, col in enumerate(cat_cols):
        ax = axes[i, 0];
        a = pp.train[col].value_counts(normalize = True);
        a.sort_index().plot.barh(ax = ax, color = '#007399');
        ax.set_title(f"{col}_Train", **CFG.title_specs);
        ax.set_xticks(np.arange(0.0, 0.9, 0.05), 
                      labels = np.round(np.arange(0.0, 0.9, 0.05),2), 
                      rotation = 90
                     );
        ax.set(xlabel = '', ylabel = '');
        del a;

        ax = axes[i, 1];
        a = pp.test[col].value_counts(normalize = True);
        a.sort_index().plot.barh(ax = ax, color = '#0088cc');
        ax.set_title(f"{col}_Test", **CFG.title_specs);
        ax.set_xticks(np.arange(0.0, 0.9, 0.05), 
                      labels = np.round(np.arange(0.0, 0.9, 0.05),2), 
                      rotation = 90
                     );
        ax.set(xlabel = '', ylabel = '');
        del a;
        
        ax = axes[i, 2];
        a = pp.original[col].value_counts(normalize = True);
        a.sort_index().plot.barh(ax = ax, color = '#0047b3');
        ax.set_title(f"{col}_Original", **CFG.title_specs);
        ax.set_xticks(np.arange(0.0, 0.9, 0.05), 
                      labels = np.round(np.arange(0.0, 0.9, 0.05),2), 
                      rotation = 90
                     );
        ax.set(xlabel = '', ylabel = '');
        del a;       
    
    plt.suptitle(f"Category column plots", **CFG.title_specs, y= 0.90);
    plt.tight_layout();
    plt.show();
    
print();
collect();
# Out:
# CPU times: user 139 ms, sys: 0 ns, total: 139 ms
# Wall time: 139 ms

# %% [markdown]
# <a id="5.7"></a>
# ## <div style= "font-family: Cambria; font-weight:bold; letter-spacing: 0px; color:#ffffff; font-size:120%; text-align:left;padding:3.0px; background: #0059b3; border-bottom: 8px solid #e6e6e6" > FEATURE INTERACTION AND UNIVARIATE RELATIONS<br><div>

# %%
# %%time 

def MakeCorrPlot(df: pd.DataFrame, data_label:str, figsize = (30, 9)):
    """
    This function develops the correlation plots for the given dataset
    """;
    
    fig, axes = plt.subplots(1,2, figsize = figsize, gridspec_kw = {'hspace': 0.2, 'wspace': 0.1},
                             sharey = True
                            );
    
    for i, method in enumerate(['pearson', 'spearman']):
        corr_ = df.drop(columns = ['id', 'Source'], errors = 'ignore').corr(method = method);
        ax = axes[i];
        sns.heatmap(data = corr_,  
                    annot= True,
                    fmt= '.2f', 
                    cmap = 'Blues',
                    annot_kws= {'fontweight': 'bold','fontsize': 6.75}, 
                    linewidths= 1.5, 
                    linecolor='white', 
                    cbar= False, 
                    mask= np.triu(np.ones_like(corr_)),
                    ax= ax
                   );
        ax.set_title(f"\n{method.capitalize()} correlation- {data_label}\n", **CFG.title_specs);
        
    collect();
    print();

# Implementing correlation analysis:-
if CFG.ftre_imp_req == "Y":
    for lbl, df in {"Train": pp.train, 
                    "Test": pp.test, 
                    "Original": pp.original
                   }.items():
        MakeCorrPlot(df = df, data_label = lbl, figsize = (22,6.5));

print();
collect();
# Out:
# CPU times: user 136 ms, sys: 0 ns, total: 136 ms
# Wall time: 136 ms

# %% [markdown]
# <a id="5.12"></a>
# ## <div style= "font-family: Cambria; font-weight:bold; letter-spacing: 0px; color:#ffffff; font-size:120%; text-align:left;padding:3.0px; background: #0059b3; border-bottom: 8px solid #e6e6e6" > INFERENCES<br> <div>

# %% [markdown]
# <div style= "font-family: Cambria; letter-spacing: 0px; color:#000000; font-size:110%; text-align:left;padding:3.0px; background: #f2f2f2" >
# 1. Features are positively and negatively skewed and are all non-negative. Feature transforms may be useful for non-tree models<br>
# 2. Outlier treatment could be considered as an option considering outlier presence across all columns in the data<br>
# 3. Higher correlation between quite a few columns may necessitate methods like PCA <br>
# </div>

# %% [markdown]
# <a id="6"></a>
# # <div style= "font-family: Cambria; font-weight:bold; letter-spacing: 0px; color:black; font-size:120%; text-align:left;padding:3.0px; background: #cceeff; border-bottom: 8px solid #004466" > DATA TRANSFORMS <br><div>
#
# This section aims at creating secondary features, scaling and if necessary, conjoining the competition training and original data tables<br>

# %%
# %%time 

# Data transforms:-
class Xformer(TransformerMixin, BaseEstimator):
    """
    This class adds secondary features to the existing data using simple interactions
    """;
    
    def __init__(self): 
        pass
    
    def fit(self, X, y= None, **params):
        return self;
    
    @staticmethod
    def _reduce_mem(df: pd.DataFrame):
        "This method reduces memory for numeric columns in the dataframe";
        
        numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
        start_mem = df.memory_usage().sum() / 1024**2;
        
        for col in df.columns:
            col_type = df[col].dtypes
            
            if col_type in numerics:
                c_min = df[col].min();
                c_max = df[col].max();

                if str(col_type)[:3] == 'int':
                    if c_min >= np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                        df[col] = df[col].astype(np.int8)
                    elif c_min >= np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                        df[col] = df[col].astype(np.int16)
                    elif c_min >= np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                        df[col] = df[col].astype(np.int32)
                    elif c_min >= np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                        df[col] = df[col].astype(np.int64)  
                else:
                    if c_min >= np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
                        df[col] = df[col].astype(np.float16)
                    if c_min >= np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                        df[col] = df[col].astype(np.float32)
                    else:
                        df[col] = df[col].astype(np.float64)  

        end_mem = df.memory_usage().sum() / 1024**2
    
        PrintColor(f"Start - end memory:- {start_mem:5.2f} - {end_mem:5.2f} Mb");
        return df;
    
    def transform(self, X, y= None, **params):
        """
        This method adds secondary features to the existing data
        """;
        
        df    = X.copy(); 
        self.op_cols = df.columns;
        df = self._reduce_mem(df);
        return df;
    
    def get_feature_names_in(self, X, y=None, **params): 
        return self.ip_cols;    
    
    def get_feature_names_out(self, X, y=None, **params): 
        return self.op_cols;
    
collect();
print();
# Out:
# CPU times: user 134 ms, sys: 0 ns, total: 134 ms
# Wall time: 134 ms

# %%
# %%time 

# Scaling:-
class Scaler(TransformerMixin, BaseEstimator):
    """
    This class aims to create scaling for the provided dataset
    """;
    
    def __init__(self, scl_method: str, scale_req: str, scl_cols):
        self.scl_method = scl_method;
        self.scale_req  = scale_req;
        self.scl_cols   = scl_cols;
        
    def fit(self,X, y=None, **params):
        "This function calculates the train-set parameters for scaling";
        
        self.params          = X[self.scl_cols].describe(percentiles = [0.25, 0.50, 0.75]).drop(['count'], axis=0).T;
        self.params['iqr']   = self.params['75%'] - self.params['25%'];
        self.params['range'] = self.params['max'] - self.params['min'];
        
        return self;
    
    def transform(self,X, y=None, **params):  
        "This function transform the relevant scaling columns";
        
        df = X.copy();
        if self.scale_req == "Y":
            if CFG.scl_method == "Z":
                df[self.scl_cols] = (df[self.scl_cols].values - self.params['mean'].values) / self.params['std'].values;
            elif CFG.scl_method == "Robust":
                df[self.scl_cols] = (df[self.scl_cols].values - self.params['50%'].values) / self.params['iqr'].values;
            elif CFG.scl_method == "MinMax":
                df[self.scl_cols] = (df[self.scl_cols].values - self.params['min'].values) / self.params['range'].values;
        else:
            PrintColor(f"Scaling is not needed", color = Fore.RED);
    
        return df;
# Out:
# CPU times: user 69 µs, sys: 0 ns, total: 69 µs
# Wall time: 72.7 µs

# %%
# %%time

PrintColor(f"\n{'='* 20} Data transformation {'='* 20} \n");

ytrain = train[CFG.target].astype(np.float32);
mapper = {209: 200, 220: 229, 230: 229, 260: 250, 410: 400, 469: 480, 
          540: 550, 575: 580, 640: 650, 664: 650, 670: 680, 810: 800, 830: 850, 
          980: 1000
         };

if CFG.tgt_scl_fct > 1:
    ytrain = (ytrain * CFG.tgt_scl_fct).astype(np.uint16);
    # Cleaning the targets:-
    for k, v in mapper.items(): 
        ytrain.loc[ytrain == k] = v;
    
Xtrain = train.drop(columns = [CFG.target]);
Xtest  = test.copy(deep = True);

PrintColor(f"\n---> Train data\n");
display(Xtrain.head(5).style.format(precision = 2));
PrintColor(f"\n---> Test data\n");
display(Xtest.head(5).style.format(precision = 2));

print();
xform  = Pipeline(steps = [("Xform", Xformer())]);
Xtrain = xform.fit_transform(Xtrain, ytrain);
Xtest  = xform.transform(Xtest);
print();

PrintColor(f"\n---> Train data columns after data pipeline\n");
pprint(Xtrain.columns);

PrintColor(f"\n---> Test data columns after data pipeline\n");
pprint(Xtest.columns);
PrintColor(f"\n---> Train-test shape after pipeline = {Xtrain.shape} {Xtest.shape}");

PrintColor(f"\n---> Dropping duplicates in the train data");
_ = pd.concat([Xtrain, ytrain], axis=1).drop_duplicates(subset = Xtrain.columns[0:-1].to_list());
_.index = range(len(_));
Xtrain, ytrain = _.drop(columns = [CFG.target]), _[CFG.target];
del _;
PrintColor(f"---> Train-test shape after duplicate removal = {Xtrain.shape} {Xtest.shape}");

print();
collect();
# Out:
# ==================== Data transformation ====================
#
#
# ---> Train data
# <style type="text/css">
# </style>
# <table id="T_4aa53">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4aa53_level0_col0" class="col_heading level0 col0" >allelectrons_Total</th>
#       <th id="T_4aa53_level0_col1" class="col_heading level0 col1" >density_Total</th>
#       <th id="T_4aa53_level0_col2" class="col_heading level0 col2" >allelectrons_Average</th>
#       <th id="T_4aa53_level0_col3" class="col_heading level0 col3" >val_e_Average</th>
#       <th id="T_4aa53_level0_col4" class="col_heading level0 col4" >atomicweight_Average</th>
#       <th id="T_4aa53_level0_col5" class="col_heading level0 col5" >ionenergy_Average</th>
#       <th id="T_4aa53_level0_col6" class="col_heading level0 col6" >el_neg_chi_Average</th>
#       <th id="T_4aa53_level0_col7" class="col_heading level0 col7" >R_vdw_element_Average</th>
#       <th id="T_4aa53_level0_col8" class="col_heading level0 col8" >R_cov_element_Average</th>
#       <th id="T_4aa53_level0_col9" class="col_heading level0 col9" >zaratio_Average</th>
#       <th id="T_4aa53_level0_col10" class="col_heading level0 col10" >density_Average</th>
#       <th id="T_4aa53_level0_col11" class="col_heading level0 col11" >Source</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >id</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4aa53_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4aa53_row0_col0" class="data row0 col0" >100</td>
#       <td id="T_4aa53_row0_col1" class="data row0 col1" >0.84</td>
#       <td id="T_4aa53_row0_col2" class="data row0 col2" >10.00</td>
#       <td id="T_4aa53_row0_col3" class="data row0 col3" >4.80</td>
#       <td id="T_4aa53_row0_col4" class="data row0 col4" >20.61</td>
#       <td id="T_4aa53_row0_col5" class="data row0 col5" >11.09</td>
#       <td id="T_4aa53_row0_col6" class="data row0 col6" >2.77</td>
#       <td id="T_4aa53_row0_col7" class="data row0 col7" >1.73</td>
#       <td id="T_4aa53_row0_col8" class="data row0 col8" >0.86</td>
#       <td id="T_4aa53_row0_col9" class="data row0 col9" >0.50</td>
#       <td id="T_4aa53_row0_col10" class="data row0 col10" >0.91</td>
#       <td id="T_4aa53_row0_col11" class="data row0 col11" >Competition</td>
#     </tr>
#     <tr>
#       <th id="T_4aa53_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_4aa53_row1_col0" class="data row1 col0" >100</td>
#       <td id="T_4aa53_row1_col1" class="data row1 col1" >7.56</td>
#       <td id="T_4aa53_row1_col2" class="data row1 col2" >10.00</td>
#       <td id="T_4aa53_row1_col3" class="data row1 col3" >4.80</td>
#       <td id="T_4aa53_row1_col4" class="data row1 col4" >20.30</td>
#       <td id="T_4aa53_row1_col5" class="data row1 col5" >12.04</td>
#       <td id="T_4aa53_row1_col6" class="data row1 col6" >2.75</td>
#       <td id="T_4aa53_row1_col7" class="data row1 col7" >1.63</td>
#       <td id="T_4aa53_row1_col8" class="data row1 col8" >0.91</td>
#       <td id="T_4aa53_row1_col9" class="data row1 col9" >0.49</td>
#       <td id="T_4aa53_row1_col10" class="data row1 col10" >0.72</td>
#       <td id="T_4aa53_row1_col11" class="data row1 col11" >Competition</td>
#     </tr>
#     <tr>
#       <th id="T_4aa53_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_4aa53_row2_col0" class="data row2 col0" >76</td>
#       <td id="T_4aa53_row2_col1" class="data row2 col1" >8.89</td>
#       <td id="T_4aa53_row2_col2" class="data row2 col2" >15.60</td>
#       <td id="T_4aa53_row2_col3" class="data row2 col3" >5.60</td>
#       <td id="T_4aa53_row2_col4" class="data row2 col4" >33.74</td>
#       <td id="T_4aa53_row2_col5" class="data row2 col5" >12.09</td>
#       <td id="T_4aa53_row2_col6" class="data row2 col6" >2.83</td>
#       <td id="T_4aa53_row2_col7" class="data row2 col7" >1.79</td>
#       <td id="T_4aa53_row2_col8" class="data row2 col8" >0.86</td>
#       <td id="T_4aa53_row2_col9" class="data row2 col9" >0.48</td>
#       <td id="T_4aa53_row2_col10" class="data row2 col10" >1.51</td>
#       <td id="T_4aa53_row2_col11" class="data row2 col11" >Competition</td>
#     </tr>
#     <tr>
#       <th id="T_4aa53_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_4aa53_row3_col0" class="data row3 col0" >100</td>
#       <td id="T_4aa53_row3_col1" class="data row3 col1" >8.80</td>
#       <td id="T_4aa53_row3_col2" class="data row3 col2" >10.00</td>
#       <td id="T_4aa53_row3_col3" class="data row3 col3" >4.80</td>
#       <td id="T_4aa53_row3_col4" class="data row3 col4" >20.21</td>
#       <td id="T_4aa53_row3_col5" class="data row3 col5" >10.95</td>
#       <td id="T_4aa53_row3_col6" class="data row3 col6" >2.65</td>
#       <td id="T_4aa53_row3_col7" class="data row3 col7" >1.63</td>
#       <td id="T_4aa53_row3_col8" class="data row3 col8" >0.94</td>
#       <td id="T_4aa53_row3_col9" class="data row3 col9" >0.49</td>
#       <td id="T_4aa53_row3_col10" class="data row3 col10" >0.79</td>
#       <td id="T_4aa53_row3_col11" class="data row3 col11" >Competition</td>
#     </tr>
#     <tr>
#       <th id="T_4aa53_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_4aa53_row4_col0" class="data row4 col0" >116</td>
#       <td id="T_4aa53_row4_col1" class="data row4 col1" >9.58</td>
#       <td id="T_4aa53_row4_col2" class="data row4 col2" >11.60</td>
#       <td id="T_4aa53_row4_col3" class="data row4 col3" >4.80</td>
#       <td id="T_4aa53_row4_col4" class="data row4 col4" >24.99</td>
#       <td id="T_4aa53_row4_col5" class="data row4 col5" >11.82</td>
#       <td id="T_4aa53_row4_col6" class="data row4 col6" >2.77</td>
#       <td id="T_4aa53_row4_col7" class="data row4 col7" >1.68</td>
#       <td id="T_4aa53_row4_col8" class="data row4 col8" >0.90</td>
#       <td id="T_4aa53_row4_col9" class="data row4 col9" >0.49</td>
#       <td id="T_4aa53_row4_col10" class="data row4 col10" >1.86</td>
#       <td id="T_4aa53_row4_col11" class="data row4 col11" >Competition</td>
#     </tr>
#   </tbody>
# </table>
# ---> Test data
# <style type="text/css">
# </style>
# <table id="T_f159d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f159d_level0_col0" class="col_heading level0 col0" >allelectrons_Total</th>
#       <th id="T_f159d_level0_col1" class="col_heading level0 col1" >density_Total</th>
#       <th id="T_f159d_level0_col2" class="col_heading level0 col2" >allelectrons_Average</th>
#       <th id="T_f159d_level0_col3" class="col_heading level0 col3" >val_e_Average</th>
#       <th id="T_f159d_level0_col4" class="col_heading level0 col4" >atomicweight_Average</th>
#       <th id="T_f159d_level0_col5" class="col_heading level0 col5" >ionenergy_Average</th>
#       <th id="T_f159d_level0_col6" class="col_heading level0 col6" >el_neg_chi_Average</th>
#       <th id="T_f159d_level0_col7" class="col_heading level0 col7" >R_vdw_element_Average</th>
#       <th id="T_f159d_level0_col8" class="col_heading level0 col8" >R_cov_element_Average</th>
#       <th id="T_f159d_level0_col9" class="col_heading level0 col9" >zaratio_Average</th>
#       <th id="T_f159d_level0_col10" class="col_heading level0 col10" >density_Average</th>
#       <th id="T_f159d_level0_col11" class="col_heading level0 col11" >Source</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >id</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f159d_level0_row0" class="row_heading level0 row0" >10407</th>
#       <td id="T_f159d_row0_col0" class="data row0 col0" >884</td>
#       <td id="T_f159d_row0_col1" class="data row0 col1" >121.42</td>
#       <td id="T_f159d_row0_col2" class="data row0 col2" >35.36</td>
#       <td id="T_f159d_row0_col3" class="data row0 col3" >5.28</td>
#       <td id="T_f159d_row0_col4" class="data row0 col4" >82.56</td>
#       <td id="T_f159d_row0_col5" class="data row0 col5" >9.37</td>
#       <td id="T_f159d_row0_col6" class="data row0 col6" >2.30</td>
#       <td id="T_f159d_row0_col7" class="data row0 col7" >1.91</td>
#       <td id="T_f159d_row0_col8" class="data row0 col8" >1.20</td>
#       <td id="T_f159d_row0_col9" class="data row0 col9" >0.46</td>
#       <td id="T_f159d_row0_col10" class="data row0 col10" >1.79</td>
#       <td id="T_f159d_row0_col11" class="data row0 col11" >Competition</td>
#     </tr>
#     <tr>
#       <th id="T_f159d_level0_row1" class="row_heading level0 row1" >10408</th>
#       <td id="T_f159d_row1_col0" class="data row1 col0" >90</td>
#       <td id="T_f159d_row1_col1" class="data row1 col1" >9.93</td>
#       <td id="T_f159d_row1_col2" class="data row1 col2" >18.00</td>
#       <td id="T_f159d_row1_col3" class="data row1 col3" >5.60</td>
#       <td id="T_f159d_row1_col4" class="data row1 col4" >39.57</td>
#       <td id="T_f159d_row1_col5" class="data row1 col5" >12.09</td>
#       <td id="T_f159d_row1_col6" class="data row1 col6" >2.87</td>
#       <td id="T_f159d_row1_col7" class="data row1 col7" >1.65</td>
#       <td id="T_f159d_row1_col8" class="data row1 col8" >0.86</td>
#       <td id="T_f159d_row1_col9" class="data row1 col9" >0.48</td>
#       <td id="T_f159d_row1_col10" class="data row1 col10" >1.41</td>
#       <td id="T_f159d_row1_col11" class="data row1 col11" >Competition</td>
#     </tr>
#     <tr>
#       <th id="T_f159d_level0_row2" class="row_heading level0 row2" >10409</th>
#       <td id="T_f159d_row2_col0" class="data row2 col0" >116</td>
#       <td id="T_f159d_row2_col1" class="data row2 col1" >7.77</td>
#       <td id="T_f159d_row2_col2" class="data row2 col2" >11.60</td>
#       <td id="T_f159d_row2_col3" class="data row2 col3" >4.80</td>
#       <td id="T_f159d_row2_col4" class="data row2 col4" >23.23</td>
#       <td id="T_f159d_row2_col5" class="data row2 col5" >11.02</td>
#       <td id="T_f159d_row2_col6" class="data row2 col6" >2.64</td>
#       <td id="T_f159d_row2_col7" class="data row2 col7" >1.79</td>
#       <td id="T_f159d_row2_col8" class="data row2 col8" >0.96</td>
#       <td id="T_f159d_row2_col9" class="data row2 col9" >0.50</td>
#       <td id="T_f159d_row2_col10" class="data row2 col10" >0.79</td>
#       <td id="T_f159d_row2_col11" class="data row2 col11" >Competition</td>
#     </tr>
#     <tr>
#       <th id="T_f159d_level0_row3" class="row_heading level0 row3" >10410</th>
#       <td id="T_f159d_row3_col0" class="data row3 col0" >100</td>
#       <td id="T_f159d_row3_col1" class="data row3 col1" >9.11</td>
#       <td id="T_f159d_row3_col2" class="data row3 col2" >10.00</td>
#       <td id="T_f159d_row3_col3" class="data row3 col3" >4.80</td>
#       <td id="T_f159d_row3_col4" class="data row3 col4" >20.30</td>
#       <td id="T_f159d_row3_col5" class="data row3 col5" >12.09</td>
#       <td id="T_f159d_row3_col6" class="data row3 col6" >2.83</td>
#       <td id="T_f159d_row3_col7" class="data row3 col7" >1.66</td>
#       <td id="T_f159d_row3_col8" class="data row3 col8" >0.79</td>
#       <td id="T_f159d_row3_col9" class="data row3 col9" >0.50</td>
#       <td id="T_f159d_row3_col10" class="data row3 col10" >1.20</td>
#       <td id="T_f159d_row3_col11" class="data row3 col11" >Competition</td>
#     </tr>
#     <tr>
#       <th id="T_f159d_level0_row4" class="row_heading level0 row4" >10411</th>
#       <td id="T_f159d_row4_col0" class="data row4 col0" >55</td>
#       <td id="T_f159d_row4_col1" class="data row4 col1" >4.03</td>
#       <td id="T_f159d_row4_col2" class="data row4 col2" >11.00</td>
#       <td id="T_f159d_row4_col3" class="data row4 col3" >4.00</td>
#       <td id="T_f159d_row4_col4" class="data row4 col4" >22.98</td>
#       <td id="T_f159d_row4_col5" class="data row4 col5" >11.28</td>
#       <td id="T_f159d_row4_col6" class="data row4 col6" >2.46</td>
#       <td id="T_f159d_row4_col7" class="data row4 col7" >1.75</td>
#       <td id="T_f159d_row4_col8" class="data row4 col8" >0.89</td>
#       <td id="T_f159d_row4_col9" class="data row4 col9" >0.48</td>
#       <td id="T_f159d_row4_col10" class="data row4 col10" >0.93</td>
#       <td id="T_f159d_row4_col11" class="data row4 col11" >Competition</td>
#     </tr>
#   </tbody>
# </table>
# Start - end memory:-  0.94 -  0.52 Mb
# Start - end memory:-  0.65 -  0.38 Mb
#
#
# ---> Train data columns after data pipeline
#
# Index(['allelectrons_Total', 'density_Total', 'allelectrons_Average',
#        'val_e_Average', 'atomicweight_Average', 'ionenergy_Average',
#        'el_neg_chi_Average', 'R_vdw_element_Average', 'R_cov_element_Average',
#        'zaratio_Average', 'density_Average', 'Source'],
#       dtype='object')
#
# ---> Test data columns after data pipeline
#
# Index(['allelectrons_Total', 'density_Total', 'allelectrons_Average',
#        'val_e_Average', 'atomicweight_Average', 'ionenergy_Average',
#        'el_neg_chi_Average', 'R_vdw_element_Average', 'R_cov_element_Average',
#        'zaratio_Average', 'density_Average', 'Source'],
#       dtype='object')
#
# ---> Train-test shape after pipeline = (11006, 12) (6939, 12)
#
# ---> Dropping duplicates in the train data
# ---> Train-test shape after duplicate removal = (10939, 12) (6939, 12)
#
# CPU times: user 204 ms, sys: 2.73 ms, total: 207 ms
# Wall time: 205 ms

# %%
# %%time 

# Shortlisting the duplicate data between train and test dataframes for post-processing:-
join_cols = Xtrain.columns[0:-1].to_list();

dups_df = \
Xtrain.\
reset_index(names = "id").\
assign(Label = "Train").\
merge(Xtest.reset_index().assign(Label = "Test"),
      how = "inner", on = join_cols, suffixes = ("_train", "_test")).\
drop(columns = join_cols).\
merge(ytrain, how = "inner", left_on = "id_train", right_index = True)\
[['id_train', 'id_test', CFG.target]].\
drop_duplicates(subset = ['id_test']);

del join_cols;

PrintColor(f"\n---> Train-test duplicate data glimpse- shape = {dups_df.shape}");
display(dups_df.head(10).style.format(precision = 3));
dups_df.to_csv(f"Duplicates.csv", index = None);

collect();
print();
# Out:
# ---> Train-test duplicate data glimpse- shape = (39, 3)
# <style type="text/css">
# </style>
# <table id="T_de2d1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_de2d1_level0_col0" class="col_heading level0 col0" >id_train</th>
#       <th id="T_de2d1_level0_col1" class="col_heading level0 col1" >id_test</th>
#       <th id="T_de2d1_level0_col2" class="col_heading level0 col2" >Hardness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_de2d1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_de2d1_row0_col0" class="data row0 col0" >580</td>
#       <td id="T_de2d1_row0_col1" class="data row0 col1" >10824</td>
#       <td id="T_de2d1_row0_col2" class="data row0 col2" >650</td>
#     </tr>
#     <tr>
#       <th id="T_de2d1_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_de2d1_row1_col0" class="data row1 col0" >580</td>
#       <td id="T_de2d1_row1_col1" class="data row1 col1" >13823</td>
#       <td id="T_de2d1_row1_col2" class="data row1 col2" >650</td>
#     </tr>
#     <tr>
#       <th id="T_de2d1_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_de2d1_row2_col0" class="data row2 col0" >1871</td>
#       <td id="T_de2d1_row2_col1" class="data row2 col1" >16403</td>
#       <td id="T_de2d1_row2_col2" class="data row2 col2" >380</td>
#     </tr>
#     <tr>
#       <th id="T_de2d1_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_de2d1_row3_col0" class="data row3 col0" >3097</td>
#       <td id="T_de2d1_row3_col1" class="data row3 col1" >12024</td>
#       <td id="T_de2d1_row3_col2" class="data row3 col2" >500</td>
#     </tr>
#     <tr>
#       <th id="T_de2d1_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_de2d1_row4_col0" class="data row4 col0" >3483</td>
#       <td id="T_de2d1_row4_col1" class="data row4 col1" >13131</td>
#       <td id="T_de2d1_row4_col2" class="data row4 col2" >600</td>
#     </tr>
#     <tr>
#       <th id="T_de2d1_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_de2d1_row5_col0" class="data row5 col0" >5956</td>
#       <td id="T_de2d1_row5_col1" class="data row5 col1" >12618</td>
#       <td id="T_de2d1_row5_col2" class="data row5 col2" >550</td>
#     </tr>
#     <tr>
#       <th id="T_de2d1_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_de2d1_row6_col0" class="data row6 col0" >6487</td>
#       <td id="T_de2d1_row6_col1" class="data row6 col1" >14760</td>
#       <td id="T_de2d1_row6_col2" class="data row6 col2" >380</td>
#     </tr>
#     <tr>
#       <th id="T_de2d1_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_de2d1_row7_col0" class="data row7 col0" >7649</td>
#       <td id="T_de2d1_row7_col1" class="data row7 col1" >12559</td>
#       <td id="T_de2d1_row7_col2" class="data row7 col2" >680</td>
#     </tr>
#     <tr>
#       <th id="T_de2d1_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_de2d1_row8_col0" class="data row8 col0" >7917</td>
#       <td id="T_de2d1_row8_col1" class="data row8 col1" >16644</td>
#       <td id="T_de2d1_row8_col2" class="data row8 col2" >580</td>
#     </tr>
#     <tr>
#       <th id="T_de2d1_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_de2d1_row9_col0" class="data row9 col0" >8111</td>
#       <td id="T_de2d1_row9_col1" class="data row9 col1" >10777</td>
#       <td id="T_de2d1_row9_col2" class="data row9 col2" >150</td>
#     </tr>
#   </tbody>
# </table>
# CPU times: user 163 ms, sys: 2.59 ms, total: 165 ms
# Wall time: 171 ms

# %%
# %%time 

# Reducing to small sample for training as part of syntax testing:-
if CFG.test_req == "Y":
    PrintColor(f"\n---> Testing syntax and reducing data size");
    
    if isinstance(CFG.test_sample_frac, float) == True:
        Xtrain = \
        pd.concat([Xtrain, ytrain], axis=1).\
        groupby([CFG.target]).\
        sample(frac = CFG.test_sample_frac);
        
       
    elif isinstance(CFG.test_sample_frac, int) == True:
        Xtrain = \
        pd.concat([Xtrain, ytrain], axis=1).\
        groupby([CFG.target]).\
        sample(n = CFG.test_sample_frac);
        
    ytrain = ytrain.loc[ytrain.index.isin(Xtrain.index)];
    Xtrain.index = range(len(Xtrain));
    ytrain.index = range(len(ytrain)); 
    
else:
    PrintColor(f"\n---> We are not testing syntax here\n");
    
PrintColor(f"---> Train-test shape after syntax check = {Xtrain.shape} {ytrain.shape} {Xtest.shape}");
    
print();
collect();
# Out:
# ---> We are not testing syntax here
#
# ---> Train-test shape after syntax check = (10939, 12) (10939,) (6939, 12)
#
# CPU times: user 135 ms, sys: 0 ns, total: 135 ms
# Wall time: 134 ms

# %% [markdown]
# <a id="7"></a>
# # <div style= "font-family: Cambria; font-weight:bold; letter-spacing: 0px; color:black; font-size:120%; text-align:left;padding:3.0px; background: #cceeff; border-bottom: 8px solid #004466" > MODEL TRAINING <br><div>

# %%
# %%time 

# Initializing model I-O:-

Mdl_Master = \
{'CBR': CatBoostRegressor(**{ 'task_type'           : "GPU" if CFG.gpu_switch == "ON" else "CPU",
                              'objective'           : 'MAE',
                              'loss_function'       : 'MAE',
                              'eval_metric'         : 'MAE',
                              'bagging_temperature' : 0.1,
                              'colsample_bylevel'   : 0.88,
                              'iterations'          : 1000,
                              'learning_rate'       : 0.06,
                              'od_wait'             : 12,
                              'max_depth'           : 7,
                              'l2_leaf_reg'         : 1.75,
                              'min_data_in_leaf'    : 20,
                              'random_strength'     : 0.1, 
                              'max_bin'             : 100,
                              'verbose'             : 0,
                              'use_best_model'      : True,
                           }
                         ), 

  'LGBM1R': LGBMRegressor(**{'device'            : "gpu" if CFG.gpu_switch == "ON" else "cpu",
                             'objective'         : 'regression_l1',
                             'metric'            : 'mae',
                             'boosting_type'     : 'gbdt',
                             'random_state'      : CFG.state,
                             'colsample_bytree'  : 0.35,
                             'subsample'         : 0.45,
                             'learning_rate'     : 0.075,
                             'max_depth'         : 4,
                             'n_estimators'      : 1000,
                             'num_leaves'        : 100,                    
                             'reg_alpha'         : 0.01,
                             'reg_lambda'        : 1.75,
                             'verbosity'         : -1,
                          }
                       ),
 
   'LGBM2R': LGBMRegressor(**{'device'              : "gpu" if CFG.gpu_switch == "ON" else "cpu",
                              'objective'           : 'regression_l1',
                              'metric'              : 'mae',
                              'boosting_type'       : 'gbdt',
                              'data_sample_strategy': "goss",
                              'random_state'        : CFG.state,
                              'colsample_bytree'    : 0.8,
                              'subsample'           : 0.85,
                              'learning_rate'       : 0.055,
                              'max_depth'           : 5,
                              'n_estimators'        : 1000,
                              'num_leaves'          : 90,                    
                              'reg_alpha'           : 0.045,
                              'reg_lambda'          : 0.533,
                              'verbosity'           : -1,
                          }
                       ),
 
   'LGBM3R': LGBMRegressor(**{'device'            : "gpu" if CFG.gpu_switch == "ON" else "cpu",
                              'objective'         : 'regression_l1',
                              'metric'            : 'mae',
                              'boosting_type'     : 'gbdt',
                              'random_state'      : CFG.state,
                              'colsample_bytree'  : 0.8,
                              'subsample'         : 0.75,
                              'learning_rate'     : 0.10,
                              'max_depth'         : 6,
                              'n_estimators'      : 1000,
                              'num_leaves'        : 78,                    
                              'reg_alpha'         : 0.0001,
                              'reg_lambda'        : 0.01,
                              'verbosity'         : -1,
                             }
                          ),
 

  'XGB1R': XGBRegressor(**{'tree_method'        : "gpu_hist" if CFG.gpu_switch == "ON" else "hist",
                           'objective'          : 'reg:absoluteerror',
                           'random_state'       : CFG.state,
                           'colsample_bytree'   : 0.7,
                           'learning_rate'      : 0.067,
                           'max_depth'          : 9,
                           'n_estimators'       : 1100,                         
                           'reg_alpha'          : 0.0035,
                           'reg_lambda'         : 0.0012,
                           'min_child_weight'   : 12,
                           'early_stopping_rounds' : CFG.nbrnd_erly_stp,
                           'eval_metric'        : "mae",
                        }
                       ),
 
  'XGB2R': XGBRegressor(**{'tree_method'         : "gpu_hist" if CFG.gpu_switch == "ON" else "hist",
                            'objective'          : 'reg:absoluteerror',
                            'random_state'       : CFG.state,
                            'colsample_bytree'   : 0.25,
                            'learning_rate'      : 0.08,
                            'max_depth'          : 8,
                            'n_estimators'       : 1100,                         
                            'reg_alpha'          : 0.1,
                            'reg_lambda'         : 0.0001,
                            'min_child_weight'   : 23,
                            'early_stopping_rounds' : CFG.nbrnd_erly_stp,
                            'eval_metric'        : "mae",
                           }
                        ), 

   "HGBR":  HGBR(loss              = "absolute_error",
                 learning_rate     = 0.09,
                 early_stopping    = True,
                 max_iter          = 200,
                 max_depth         = 5,
                 min_samples_leaf  = 23,
                 l2_regularization = 1.75,
                 scoring           = myscorer,
                 random_state      = CFG.state,
                ),
 
  "GBR" : GBR(loss          = 'absolute_error',
              learning_rate = 0.055,
              n_estimators  = 250,
              subsample     = 0.45,
              min_samples_leaf= 26,
              max_depth       = 5,
              random_state    = CFG.state,
              n_iter_no_change= CFG.nbrnd_erly_stp,
              tol             = 0.0001,
             ),
};

print();
collect();
# Out:
# CPU times: user 136 ms, sys: 566 µs, total: 137 ms
# Wall time: 140 ms

# %%
# %%time

if CFG.ML == "Y":

    # Initializing output tables for the models:-
    if CFG.test_req == "Y" or CFG.pseudo_lbl_req == "Y":
        methods = ["LGBM1R", "LGBM2R", "XGB1R", 'XGB2R'];
    else:
        methods = list(Mdl_Master.keys());
  
    sel_cols  = Xtrain.columns.to_list();
    cat_ftre  = cat_cols;
    scl_ftre  = cont_cols;
    
    if CFG.mdlcv_mthd in ("SKF", "RSKF"):
        y_grp = np.uint8(ytrain / CFG.tgt_scl_fct);
    else:
        y_grp = ytrain.values;
    
    OOF_Preds = pd.DataFrame(columns = methods);
    Mdl_Preds = pd.DataFrame(index = pp.sub_fl['id'], columns = methods);
    FtreImp   = pd.DataFrame(index = sel_cols[0:-1], columns = methods);
    Scores    = pd.DataFrame(columns = methods);

    PrintColor(f"\n---> Selected model options- ");
    pprint(methods, depth = 1, width = 100, indent = 5);
    
    PrintColor(f"\n---> Selected category columns- ");
    pprint(np.array(cat_ftre), depth = 1, width = 100, indent = 5);
    
    PrintColor(f"\n---> Selected transformation columns- ");
    pprint(np.array(scl_ftre), depth = 1, width = 100, indent = 5);

print();
collect();
# Out:
# ---> Selected model options-
# ['CBR', 'LGBM1R', 'LGBM2R', 'LGBM3R', 'XGB1R', 'XGB2R', 'HGBR', 'GBR']
#
# ---> Selected category columns-
# array([], dtype=float64)
#
# ---> Selected transformation columns-
# array(['allelectrons_Total', 'density_Total', 'allelectrons_Average',
#        'val_e_Average', 'atomicweight_Average', 'ionenergy_Average',
#        'el_neg_chi_Average', 'R_vdw_element_Average',
#        'R_cov_element_Average', 'zaratio_Average', 'density_Average'],
#       dtype='<U21')
#
# CPU times: user 141 ms, sys: 202 µs, total: 141 ms
# Wall time: 141 ms

# %%
# %%time 

def TrainMdl(method:str):
    
    global Mdl_Master, Mdl_Preds, OOF_Preds, \
    all_cv, FtreImp, Xtrain, ytrain, y_grp, \
    sel_cols, risk_ftre, scl_ftre ; 
    
    if method.startswith("KNN") or method.startswith("RIDGE") or \
    method.startswith("LT") == True or method.startswith("SV") == True:
        c_xform = \
        ColumnTransformer([("CXform", all_scalers[CFG.scl_method], scl_ftre)
                          ], remainder = 'passthrough', verbose_feature_names_out = False
                         ); 
        model = Pipeline(steps = [("T", c_xform), ("M", Mdl_Master.get(method))]); 
         
    else: 
        model = Pipeline(steps = [("M", Mdl_Master.get(method))]); 
    
    cv        = all_cv.get(CFG.mdlcv_mthd);
    Xt        = Xtest[sel_cols];
    
    if CFG.use_orig_allfolds == "Y":
        X    = Xtrain[sel_cols].query("Source == 'Competition'");
        y    = ytrain.loc[ytrain.index.isin(X.index)]; 
        Orig = pd.concat([Xtrain, ytrain], axis=1).query("Source == 'Original'")[sel_cols];
        
    elif CFG.use_orig_allfolds != "Y":
        X,y = Xtrain[sel_cols], ytrain.copy(deep = True);
                  
    # Initializing I-O for the given seed:-        
    test_preds = 0;
    oof_preds  = pd.DataFrame(); 
    scores     = [];
    ftreimp    = 0;
    cols_drop  = ['Source', "id"];
       
    for fold_nb, (train_idx, dev_idx) in enumerate(cv.split(X, y_grp)):
        Xtr  = X.iloc[train_idx].drop(columns = cols_drop, errors = 'ignore');  
        Xdev = X.iloc[dev_idx].loc[X.Source == "Competition"].\
        drop(columns = cols_drop, errors = 'ignore'); 
        ytr  = y.loc[y.index.isin(Xtr.index)];
        ydev = y.loc[y.index.isin(Xdev.index)];
        
        if CFG.test_req == "Y":
            print(f"---> {Xtr.shape} {Xdev.shape} {ytr.shape} {ydev.shape} {Xt.shape}");
        else:
            pass;

        if CFG.use_orig_allfolds == "Y":
            Xtr = pd.concat([Xtr, Orig.drop(columns = [CFG.target, 'Source'], errors = 'ignore')], 
                            axis = 0, ignore_index = True);
            ytr = pd.concat([ytr, Orig[CFG.target]], axis = 0, ignore_index = True);
            
        # Fitting the model:- 
        if "CB" in method:    
            model.fit(Xtr, ytr, 
                      M__eval_set = [(Xdev, ydev)], 
                      M__verbose = 0,
                      M__early_stopping_rounds = CFG.nbrnd_erly_stp,
                     ); 
        
        elif "LGBM" in method:
            model.fit(Xtr, ytr, 
                      M__eval_set = [(Xdev, ydev)], 
                      M__callbacks = [log_evaluation(0), 
                                      early_stopping(stopping_rounds = CFG.nbrnd_erly_stp, 
                                                     verbose = False,)
                                     ]
                     ); 
            
        elif "XGB" in method:
             model.fit(Xtr, ytr, M__eval_set = [(Xdev, ydev)], M__verbose = 0,);            
            
        else: 
            model.fit(Xtr, ytr); 
                 
        # Collecting predictions and scores and post-processing OOF based on model method:-
        dev_preds   = PostProcessPred(model.predict(Xdev), post_process= CFG.pstprcs_train);
        test_preds  = test_preds + \
        PostProcessPred(model.predict(Xt.drop(columns = cols_drop, errors = 'ignore')),
                        post_process= CFG.pstprcs_train);
        train_preds = PostProcessPred(model.predict(Xtr), post_process= CFG.pstprcs_train);
          
        tr_score = ScoreMetric(ytr.values.flatten(), train_preds);
        score = ScoreMetric(ydev.values.flatten(), dev_preds);
        scores.append(score); 
        
        Scores.loc[fold_nb, method] = np.round(score, decimals= 6);
        oof_preds = pd.concat([oof_preds,
                               pd.DataFrame(index   = Xdev.index, 
                                            data    = dev_preds,
                                            columns = [method])
                              ],axis=0, ignore_index= False
                             ); 
        
        num_space = 3 if fold_nb <= 9 else 2;
        PrintColor(f"Fold{fold_nb} {' ' * num_space} OOF = {score:.5f} | Train = {tr_score:.5f}| {method}", 
                   color = Fore.GREEN);
        del num_space;
    
        oof_preds = pd.DataFrame(oof_preds.groupby(level = 0)[method].mean());
        oof_preds.columns = [method];
        
        try: 
            ftreimp += model["M"].feature_importances_;
        except: 
            ftreimp = 0;
            
    num_space = 10 - len(method);
    PrintColor(f"--> {method}{'-' * num_space} CV = {np.mean(scores):.6f}\n");
    del num_space;
    
    OOF_Preds[f'{method}'] = PostProcessPred(oof_preds.values.flatten(), CFG.pstprcs_train);
    
    if CFG.mdlcv_mthd in ['KF', 'SKF']:
        Mdl_Preds[f'{method}'] = test_preds.flatten()/ CFG.n_splits; 
        FtreImp[method]        = ftreimp / CFG.n_splits;
    else:
        Mdl_Preds[f'{method}'] = test_preds.flatten()/ (CFG.n_splits * CFG.n_repeats); 
        FtreImp[method]        = ftreimp / (CFG.n_splits * CFG.n_repeats);
    
    collect(); 
    
print();
collect();
# Out:
# CPU times: user 134 ms, sys: 716 µs, total: 134 ms
# Wall time: 134 ms

# %%
# %%time 

def MakePseudoLbl(Mdl_Preds: pd.DataFrame, ytrain: pd.Series, 
                  Xtrain: pd.DataFrame, Xtest: pd.DataFrame, 
                  up_cutoff: float, low_cutoff: float,
                  **kwargs
                 ):
    "This function combines the confident test-set predictions to the train set for 2nd stage pseudo labels";
    
    test_preds = np.mean(Mdl_Preds, axis=1).to_frame();
    test_preds.rename(columns = {0: CFG.target}, inplace = True);
    test_preds[CFG.target] = np.select([test_preds[CFG.target].values >= 0.90, 
                                        test_preds[CFG.target].values <= 0.05
                                       ], [1, 0], -1
                                      );
    test_preds = test_preds.loc[test_preds[CFG.target] >= 0];
    
    display(test_preds.head(10));
    
    PrintColor(f"Rows to be added to the training data = {test_preds.shape[0]}");
    
    test_preds = pd.concat([Xtest, test_preds], axis=1, join= "inner");
    
    Xtrain = pd.concat([Xtrain, test_preds[Xtrain.columns]], axis=0, ignore_index = True);
    Xtrain.index = range(len(Xtrain));
    ytrain = pd.concat([ytrain, test_preds[CFG.target].astype(np.uint8)], 
                       axis=0, ignore_index = True
                      );
    ytrain.index = range(len(ytrain));
    
    PrintColor(f"Training data shape for 2nd stage pseudo labels = {Xtrain.shape} {ytrain.shape}");
    
    return Xtrain, ytrain;
# Out:
# CPU times: user 0 ns, sys: 9 µs, total: 9 µs
# Wall time: 12.9 µs

# %%
# %%time

if CFG.pseudo_lbl_req == "Y" and CFG.ML == "Y":
    # Implementing the ML models for 1st stage pseudo labels:-
    PrintColor(f"\n{'-' * 25} ML model training- Stage1 Pseudo Labels {'-' * 25}\n", 
               color = Fore.MAGENTA
              );
    for method in tqdm(methods, "ML models----"): 
        TrainMdl(method);
   
    PrintColor(f"\n{'-' * 20} OOF CV scores across methods- Stage1 Pseudo Labels {'-' * 20}\n", 
                   color = Fore.MAGENTA);
    display(pd.concat([Scores.mean(axis = 0), Scores.std(axis = 0)], axis=1).\
            rename(columns = {0: 'Mean', 1: 'Std'}).T.\
            style.format(precision = 6).\
            background_gradient(subset = methods, cmap = 'cubehelix', axis=1)
           );  
    
    # Combining confident test-set predictions to the train-set:- 
    Xtrain, ytrain = MakePseudoLbl(**{'Mdl_Preds': Mdl_Preds, 
                                      'ytrain'   : ytrain, 
                                      'Xtrain'   : Xtrain, 
                                      'Xtest'    : Xtest, 
                                      'up_cutoff': CFG.pseudolbl_up,
                                      'low_cutoff': CFG.pseudolbl_low,
                                     }
                                  );
        
    # Initializig I-O for second stage pseudo labels:-
    if CFG.test_req == "Y":
        methods = ["LGBM1R", "XGB1R", "LGBM2R"];
    else:
        methods = list(Mdl_Master.keys());
        
    OOF_Preds = pd.DataFrame(columns = methods);
    Mdl_Preds = pd.DataFrame(index = pp.sub_fl['id'], columns = methods);
    FtreImp   = pd.DataFrame(index = sel_cols[1:], columns = methods);
    Scores    = pd.DataFrame(columns = methods);
    
    PrintColor(f"\n---> Selected model options- ");
    pprint(methods, depth = 1, width = 100, indent = 5);
    
    PrintColor(f"\n{'-' * 25} ML model training- Stage2 Pseudo Labels {'-' * 25}\n", 
               color = Fore.MAGENTA
              );
    for method in tqdm(methods, "ML models----"): TrainMdl(method);
    
    PrintColor(f"\n{'-' * 20} OOF CV scores across methods- Stage2 Pseudo Labels {'-' * 20}\n", 
                   color = Fore.MAGENTA);
    display(pd.concat([Scores.mean(axis = 0), Scores.std(axis = 0)], axis=1).\
            rename(columns = {0: 'Mean', 1: 'Std'}).T.\
            style.format(precision = 6).\
            background_gradient(subset = methods, cmap = 'cubehelix', axis=1)
           ); 
    
elif CFG.ML == "Y":
    PrintColor(f"\n{'-' * 25} ML model training {'-' * 25}\n", color = Fore.MAGENTA);
    for method in tqdm(methods, "ML models----"): 
        TrainMdl(method);

    PrintColor(f"\n{'-' * 20} OOF CV scores across methods {'-' * 20}\n", 
               color = Fore.MAGENTA);
    display(pd.concat([Scores.mean(axis = 0), Scores.std(axis = 0)], axis=1).\
            rename(columns = {0: 'Mean', 1: 'Std'}).T.\
            style.format(precision = 6).\
            background_gradient(subset = methods, cmap = 'cubehelix', axis=1)
           );    
else:
    PrintColor(f"\nML models are not needed\n", color = Fore.RED);    

collect();
print();
# Out:
# ------------------------- ML model training -------------------------
# ML models----:   0%|          | 0/8 [00:00<?, ?it/s]
# Fold0     OOF = 52.50310 | Train = 42.74813| CBR
# Fold1     OOF = 52.82330 | Train = 36.73268| CBR
# Fold2     OOF = 55.61248 | Train = 32.84650| CBR
# Fold3     OOF = 48.44710 | Train = 38.19495| CBR
# Fold4     OOF = 57.44885 | Train = 43.17123| CBR
# Fold5     OOF = 53.83817 | Train = 41.78693| CBR
# Fold6     OOF = 54.86555 | Train = 36.99407| CBR
# Fold7     OOF = 55.36518 | Train = 35.48369| CBR
# Fold8     OOF = 58.53793 | Train = 38.68561| CBR
# Fold9     OOF = 49.96793 | Train = 35.34908| CBR
# --> CBR------- CV = 53.940960
#
# Fold0     OOF = 53.50865 | Train = 47.10550| LGBM1R
# Fold1     OOF = 54.28339 | Train = 45.42512| LGBM1R
# Fold2     OOF = 54.23113 | Train = 45.32402| LGBM1R
# Fold3     OOF = 49.48267 | Train = 42.96532| LGBM1R
# Fold4     OOF = 54.40589 | Train = 40.58074| LGBM1R
# Fold5     OOF = 53.10751 | Train = 43.92724| LGBM1R
# Fold6     OOF = 60.54591 | Train = 47.02758| LGBM1R
# Fold7     OOF = 56.71718 | Train = 40.69732| LGBM1R
# Fold8     OOF = 56.03687 | Train = 39.35541| LGBM1R
# Fold9     OOF = 52.21959 | Train = 44.54172| LGBM1R
# --> LGBM1R---- CV = 54.453880
#
# Fold0     OOF = 53.36423 | Train = 38.74091| LGBM2R
# Fold1     OOF = 52.17202 | Train = 42.24052| LGBM2R
# Fold2     OOF = 51.54032 | Train = 40.01652| LGBM2R
# Fold3     OOF = 48.71871 | Train = 40.82604| LGBM2R
# Fold4     OOF = 57.63319 | Train = 38.35967| LGBM2R
# Fold5     OOF = 53.53929 | Train = 41.17734| LGBM2R
# Fold6     OOF = 54.93981 | Train = 40.75734| LGBM2R
# Fold7     OOF = 53.33308 | Train = 40.45179| LGBM2R
# Fold8     OOF = 53.87913 | Train = 35.50119| LGBM2R
# Fold9     OOF = 49.91875 | Train = 38.75813| LGBM2R
# --> LGBM2R---- CV = 52.903852
#
# Fold0     OOF = 50.57827 | Train = 39.20893| LGBM3R
# Fold1     OOF = 52.08065 | Train = 37.91763| LGBM3R
# Fold2     OOF = 51.90423 | Train = 33.01694| LGBM3R
# Fold3     OOF = 50.00116 | Train = 30.19193| LGBM3R
# Fold4     OOF = 54.66148 | Train = 31.67830| LGBM3R
# Fold5     OOF = 52.72760 | Train = 43.24179| LGBM3R
# Fold6     OOF = 54.76217 | Train = 36.61669| LGBM3R
# Fold7     OOF = 53.27325 | Train = 34.63446| LGBM3R
# Fold8     OOF = 52.71779 | Train = 29.53351| LGBM3R
# Fold9     OOF = 49.58508 | Train = 32.34428| LGBM3R
# --> LGBM3R---- CV = 52.229168
#
# Fold0     OOF = 53.10834 | Train = 28.58014| XGB1R
# Fold1     OOF = 50.73282 | Train = 24.22540| XGB1R
# Fold2     OOF = 51.38136 | Train = 26.59671| XGB1R
# Fold3     OOF = 48.54333 | Train = 25.29785| XGB1R
# Fold4     OOF = 53.39658 | Train = 25.38177| XGB1R
# Fold5     OOF = 52.57274 | Train = 29.80724| XGB1R
# Fold6     OOF = 58.42303 | Train = 29.54083| XGB1R
# Fold7     OOF = 53.00233 | Train = 25.34790| XGB1R
# Fold8     OOF = 51.83243 | Train = 22.91040| XGB1R
# Fold9     OOF = 49.15335 | Train = 23.30923| XGB1R
# --> XGB1R----- CV = 52.214630
#
# Fold0     OOF = 53.83029 | Train = 34.91302| XGB2R
# Fold1     OOF = 52.92218 | Train = 39.46387| XGB2R
# Fold2     OOF = 55.14050 | Train = 35.02832| XGB2R
# Fold3     OOF = 51.82648 | Train = 36.09381| XGB2R
# Fold4     OOF = 56.47601 | Train = 31.64679| XGB2R
# Fold5     OOF = 55.00134 | Train = 37.19141| XGB2R
# Fold6     OOF = 60.35632 | Train = 34.19275| XGB2R
# Fold7     OOF = 56.53264 | Train = 34.38733| XGB2R
# Fold8     OOF = 53.48990 | Train = 28.48553| XGB2R
# Fold9     OOF = 50.18585 | Train = 38.40265| XGB2R
# --> XGB2R----- CV = 54.576149
#
# Fold0     OOF = 50.87126 | Train = 49.38039| HGBR
# Fold1     OOF = 53.33015 | Train = 50.70140| HGBR
# Fold2     OOF = 54.63865 | Train = 50.19229| HGBR
# Fold3     OOF = 52.79635 | Train = 50.42990| HGBR
# Fold4     OOF = 57.83105 | Train = 49.23749| HGBR
# Fold5     OOF = 54.55937 | Train = 50.15694| HGBR
# Fold6     OOF = 55.98348 | Train = 50.20375| HGBR
# Fold7     OOF = 56.29587 | Train = 49.67658| HGBR
# Fold8     OOF = 57.88420 | Train = 47.80575| HGBR
# Fold9     OOF = 51.97967 | Train = 50.23574| HGBR
# --> HGBR------ CV = 54.617006
#
# Fold0     OOF = 52.85005 | Train = 46.81833| GBR
# Fold1     OOF = 54.52910 | Train = 47.14061| GBR
# Fold2     OOF = 52.57563 | Train = 47.74729| GBR
# Fold3     OOF = 50.15352 | Train = 46.97258| GBR
# Fold4     OOF = 58.53814 | Train = 47.66529| GBR
# Fold5     OOF = 53.01255 | Train = 46.76459| GBR
# Fold6     OOF = 58.55309 | Train = 47.51304| GBR
# Fold7     OOF = 54.69535 | Train = 47.17684| GBR
# Fold8     OOF = 57.20912 | Train = 46.84619| GBR
# Fold9     OOF = 51.46899 | Train = 47.35742| GBR
# --> GBR------- CV = 54.358553
#
#
# -------------------- OOF CV scores across methods --------------------
# <style type="text/css">
# #T_34a85_row0_col0 {
#   background-color: #cca4e2;
#   color: #000000;
# }
# #T_34a85_row0_col1 {
#   background-color: #e0f5f0;
#   color: #000000;
# }
# #T_34a85_row0_col2 {
#   background-color: #1b6145;
#   color: #f1f1f1;
# }
# #T_34a85_row0_col3 {
#   background-color: #020102;
#   color: #f1f1f1;
# }
# #T_34a85_row0_col4, #T_34a85_row1_col3 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_34a85_row0_col5 {
#   background-color: #f8fdfa;
#   color: #000000;
# }
# #T_34a85_row0_col6, #T_34a85_row1_col0 {
#   background-color: #ffffff;
#   color: #000000;
# }
# #T_34a85_row0_col7 {
#   background-color: #d0ecef;
#   color: #000000;
# }
# #T_34a85_row1_col1 {
#   background-color: #c5dff2;
#   color: #000000;
# }
# #T_34a85_row1_col2 {
#   background-color: #bc7967;
#   color: #f1f1f1;
# }
# #T_34a85_row1_col4 {
#   background-color: #cf9fdd;
#   color: #000000;
# }
# #T_34a85_row1_col5 {
#   background-color: #c2c3f2;
#   color: #000000;
# }
# #T_34a85_row1_col6 {
#   background-color: #7b7a35;
#   color: #f1f1f1;
# }
# #T_34a85_row1_col7 {
#   background-color: #c3daf2;
#   color: #000000;
# }
# </style>
# <table id="T_34a85">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_34a85_level0_col0" class="col_heading level0 col0" >CBR</th>
#       <th id="T_34a85_level0_col1" class="col_heading level0 col1" >LGBM1R</th>
#       <th id="T_34a85_level0_col2" class="col_heading level0 col2" >LGBM2R</th>
#       <th id="T_34a85_level0_col3" class="col_heading level0 col3" >LGBM3R</th>
#       <th id="T_34a85_level0_col4" class="col_heading level0 col4" >XGB1R</th>
#       <th id="T_34a85_level0_col5" class="col_heading level0 col5" >XGB2R</th>
#       <th id="T_34a85_level0_col6" class="col_heading level0 col6" >HGBR</th>
#       <th id="T_34a85_level0_col7" class="col_heading level0 col7" >GBR</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_34a85_level0_row0" class="row_heading level0 row0" >Mean</th>
#       <td id="T_34a85_row0_col0" class="data row0 col0" >53.940960</td>
#       <td id="T_34a85_row0_col1" class="data row0 col1" >54.453880</td>
#       <td id="T_34a85_row0_col2" class="data row0 col2" >52.903852</td>
#       <td id="T_34a85_row0_col3" class="data row0 col3" >52.229168</td>
#       <td id="T_34a85_row0_col4" class="data row0 col4" >52.214630</td>
#       <td id="T_34a85_row0_col5" class="data row0 col5" >54.576147</td>
#       <td id="T_34a85_row0_col6" class="data row0 col6" >54.617006</td>
#       <td id="T_34a85_row0_col7" class="data row0 col7" >54.358553</td>
#     </tr>
#     <tr>
#       <th id="T_34a85_level0_row1" class="row_heading level0 row1" >Std</th>
#       <td id="T_34a85_row1_col0" class="data row1 col0" >3.134207</td>
#       <td id="T_34a85_row1_col1" class="data row1 col1" >2.929418</td>
#       <td id="T_34a85_row1_col2" class="data row1 col2" >2.518464</td>
#       <td id="T_34a85_row1_col3" class="data row1 col3" >1.786301</td>
#       <td id="T_34a85_row1_col4" class="data row1 col4" >2.736070</td>
#       <td id="T_34a85_row1_col5" class="data row1 col5" >2.841250</td>
#       <td id="T_34a85_row1_col6" class="data row1 col6" >2.395625</td>
#       <td id="T_34a85_row1_col7" class="data row1 col7" >2.917940</td>
#     </tr>
#   </tbody>
# </table>
# CPU times: user 3min 49s, sys: 9.84 s, total: 3min 59s
# Wall time: 3min 10s

# %%
# %%time 

# Analysing the model results and feature importances:-
if CFG.ML == "Y":
    fig, axes = plt.subplots(len(methods), 1, figsize = (25, len(methods) * 6),
                             gridspec_kw = {'hspace': 0.2, 'wspace': 0.2},
                            );
    
    for i, col in enumerate(methods):
        try: 
            ax = axes[i];
        except: 
            ax = axes[0];
        FtreImp[col].plot.barh(ax = ax, color = '#0073e6');
        ax.set_title(f"{col} Importances", **CFG.title_specs);
        ax.set(xlabel = '', ylabel = '');
        
    plt.suptitle(f"ML Model prediction feature importance", y = 0.9125, **CFG.title_specs);
    plt.tight_layout();
    plt.show();  

collect();
# Out:
# CPU times: user 3.3 s, sys: 171 ms, total: 3.47 s
# Wall time: 3.5 s

# %% [markdown]
# ## <div style= "font-family: Cambria; font-weight:bold; letter-spacing: 0px; color:#ffffff; font-size:120%; text-align:left;padding:3.0px; background: #0059b3; border-bottom: 8px solid #e6e6e6" > INFERENCES<br> <div>

# %% [markdown]
# <div style= "font-family: Cambria; letter-spacing: 0px; color:#000000; font-size:110%; text-align:left;padding:3.0px; background: #f2f2f2" >
# 1. We have to drop some features/ add secondary features to ensue better CV results. Train-OOF scores are very stable. <br>
# 2. We need to fine-tune some model parameters too<br>
# 3. We could try other model methods too, perhaps some simpler ones will be good enough <br>
# 4. Custom objective/ metric class will also work in this case <br>
# 5. We can explore pseudo labels also <br>
# </div>

# %% [markdown]
# <a id="8"></a>
# # <div style= "font-family: Cambria; font-weight:bold; letter-spacing: 0px; color:black; font-size:120%; text-align:left;padding:3.0px; background: #cceeff; border-bottom: 8px solid #004466" > ENSEMBLE AND SUBMISSION<br> <div>

# %%
# %%time 

if CFG.ensemble_req == "Y" and CFG.optuna_req == "Y":
    def Objective(trial):
        "This function defines the objective for the optuna ensemble using variable models";

        global OOF_Preds, all_cv, ytrain, methods, y_grp;

        # Define the weights for the predictions from each model:-
        weights  = [trial.suggest_float(f"M{n}", 0.0001, 0.9999, step = 0.001) \
                    for n in range(len(OOF_Preds[methods].columns))
                   ];

        # Calculating the CV-score for the weighted predictions on the competition data only:-
        scores = [];  
        cv     = all_cv[CFG.enscv_mthd];
        X,y    = OOF_Preds[methods], ytrain[0: len(OOF_Preds)];

        for fold_nb, (train_idx, dev_idx) in enumerate(cv.split(X,y_grp[0: len(OOF_Preds)])):
            Xtr, Xdev = X.iloc[train_idx], X.iloc[dev_idx];
            ytr, ydev = y.loc[Xtr.index],  y.loc[Xdev.index];
            scores.append(ScoreMetric(ydev, np.average(Xdev, axis=1, weights = weights)));

        collect();
        clear_output();
        return np.mean(scores);
    
clear_output();
print();
collect();
# Out:
# CPU times: user 152 ms, sys: 0 ns, total: 152 ms
# Wall time: 152 ms

# %%
# %%time 

if CFG.ensemble_req == "Y" and CFG.optuna_req == "Y":   
    PrintColor(f"\n{'-' * 20} Creating an Optuna Ensemble {'-' * 20}\n", 
               color = Fore.MAGENTA);   
    
    study = optuna.create_study(direction  = CFG.metric_obj, 
                                study_name = "OptunaEnsemble", 
                                sampler    = TPESampler(seed = CFG.state)
                               );
    study.optimize(Objective, 
                   n_trials          = CFG.ntrials, 
                   gc_after_trial    = True,
                   show_progress_bar = True
                  );
    weights       = study.best_params;
    clear_output();
    
    PrintColor(f"\n--> Post ensemble weights\n");
    pprint(weights, indent = 5, width = 10, depth = 1);
    PrintColor(f"\n--> Best ensemble CV score = {study.best_value :.5f}\n");
    
    # Making weighted predictions on the test set:-
    sub_fl[CFG.target] = np.average(Mdl_Preds[methods], weights = list(weights.values()),
                                    axis=1
                                   ) / CFG.tgt_scl_fct;
    
    # Making OOF predictions:-
    OOF_Preds["Optuna"] = np.average(OOF_Preds[methods], weights = list(weights.values()),
                                     axis=1
                                    ) / CFG.tgt_scl_fct;
    
    PrintColor(f"\n--> Post ensemble test-set predictions\n");
    display(sub_fl.head(5).style.format(precision = 5)); 
      
collect();
print();
# Out:
# CPU times: user 152 ms, sys: 997 µs, total: 153 ms
# Wall time: 153 ms

# %%
# %%time 

# Source - https://www.kaggle.com/competitions/playground-series-s3e25/discussion/455289

if CFG.ensemble_req == "Y" and CFG.LAD_req == "Y":
    PrintColor(f"\n{'-' * 20} Creating an LADR Ensemble {'-' * 20}\n", color = Fore.MAGENTA); 
    X,y        = OOF_Preds[methods], ytrain[0: len(OOF_Preds)];
    model      = LADR();
    test_preds = 0;
    scores     = [];
    cv         = all_cv[CFG.enscv_mthd];
    ens_preds  = pd.DataFrame(columns = ["LAD"]);

    for fold_nb, (train_idx, dev_idx) in enumerate(cv.split(X, y_grp[0:len(X)])):
        Xtr  = X.iloc[train_idx];  
        Xdev = X.iloc[dev_idx]; 
        ytr  = y.loc[y.index.isin(Xtr.index)];
        ydev = y.loc[y.index.isin(Xdev.index)];

        model.fit(Xtr, ytr);
        dev_preds  = PostProcessPred(model.predict(Xdev), CFG.pstprcs_train);
        score      = ScoreMetric(ydev, dev_preds);
        test_preds = test_preds + \
        PostProcessPred(model.predict(Mdl_Preds[methods]), CFG.pstprcs_train);
        scores.append(score);
        
        ens_preds = pd.concat([ens_preds, 
                               pd.DataFrame(dev_preds, columns = ['LAD'], index = Xdev.index)], 
                              axis=0
                             );

    test_preds         = test_preds/ (CFG.n_splits * CFG.n_repeats);
    sub_fl[CFG.target] = test_preds/ CFG.tgt_scl_fct;
    ens_preds          = ens_preds.groupby(level = 0).mean().values;
    OOF_Preds["LAD"]   = ens_preds;
    
    PrintColor(f"---> OOF scores for the LAD ensemble");
    with np.printoptions(linewidth = 160, precision= 4):
        pprint(np.array(scores), indent = 10, depth = 1);
        PrintColor(f"---> Mean OOF scores for the LAD ensemble = {np.mean(scores):.5f}");
        
    PrintColor(f"\n--> Post ensemble test-set predictions\n");
    display(sub_fl.head(5).style.format(precision = 5)); 
    
    # Analyzing the grouped predictions for edge case issues:-  
    PrintColor(f"\n--> Analysis of grouped predictions on OOF data\n");
    OOF_Preds['Grp'] = y_grp[0: len(OOF_Preds)];
    OOF_Preds        = pd.concat([OOF_Preds, ytrain[0: len(OOF_Preds)]], axis=1);
    
    display(OOF_Preds[["Grp", CFG.target, "LAD"]].\
            groupby("Grp").\
            apply(lambda x: ScoreMetric(x[CFG.target], x["LAD"])).\
            to_frame().rename(columns = {0: "OOFScore"}).\
            style.format(precision = 4).\
            background_gradient("icefire")
           );

print();
collect();
# Out:
# -------------------- Creating an LADR Ensemble --------------------
#
# ---> OOF scores for the LAD ensemble
# array([50.2598, 54.1474, 53.4477, 49.9484, 54.0835, 50.9752, 59.653 , 51.6849, 47.6149, 48.047 ])
# ---> Mean OOF scores for the LAD ensemble = 51.98618
#
# --> Post ensemble test-set predictions
# <style type="text/css">
# </style>
# <table id="T_1f6ff">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1f6ff_level0_col0" class="col_heading level0 col0" >id</th>
#       <th id="T_1f6ff_level0_col1" class="col_heading level0 col1" >Hardness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1f6ff_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1f6ff_row0_col0" class="data row0 col0" >10407</td>
#       <td id="T_1f6ff_row0_col1" class="data row0 col1" >2.69293</td>
#     </tr>
#     <tr>
#       <th id="T_1f6ff_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_1f6ff_row1_col0" class="data row1 col0" >10408</td>
#       <td id="T_1f6ff_row1_col1" class="data row1 col1" >2.50375</td>
#     </tr>
#     <tr>
#       <th id="T_1f6ff_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_1f6ff_row2_col0" class="data row2 col0" >10409</td>
#       <td id="T_1f6ff_row2_col1" class="data row2 col1" >5.99916</td>
#     </tr>
#     <tr>
#       <th id="T_1f6ff_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_1f6ff_row3_col0" class="data row3 col0" >10410</td>
#       <td id="T_1f6ff_row3_col1" class="data row3 col1" >4.48761</td>
#     </tr>
#     <tr>
#       <th id="T_1f6ff_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_1f6ff_row4_col0" class="data row4 col0" >10411</td>
#       <td id="T_1f6ff_row4_col1" class="data row4 col1" >5.15695</td>
#     </tr>
#   </tbody>
# </table>
# --> Analysis of grouped predictions on OOF data
# <style type="text/css">
# #T_1f18a_row0_col0 {
#   background-color: #2b2a40;
#   color: #f1f1f1;
# }
# #T_1f18a_row1_col0 {
#   background-color: #3b3866;
#   color: #f1f1f1;
# }
# #T_1f18a_row2_col0 {
#   background-color: #494a9a;
#   color: #f1f1f1;
# }
# #T_1f18a_row3_col0, #T_1f18a_row15_col0 {
#   background-color: #4394ce;
#   color: #f1f1f1;
# }
# #T_1f18a_row4_col0 {
#   background-color: #377fd0;
#   color: #f1f1f1;
# }
# #T_1f18a_row5_col0, #T_1f18a_row9_col0 {
#   background-color: #53a2cd;
#   color: #f1f1f1;
# }
# #T_1f18a_row6_col0 {
#   background-color: #63adcd;
#   color: #f1f1f1;
# }
# #T_1f18a_row7_col0 {
#   background-color: #3a89cf;
#   color: #f1f1f1;
# }
# #T_1f18a_row8_col0, #T_1f18a_row27_col0 {
#   background-color: #3878cf;
#   color: #f1f1f1;
# }
# #T_1f18a_row10_col0 {
#   background-color: #bde7db;
#   color: #000000;
# }
# #T_1f18a_row11_col0 {
#   background-color: #4192ce;
#   color: #f1f1f1;
# }
# #T_1f18a_row12_col0 {
#   background-color: #3885d0;
#   color: #f1f1f1;
# }
# #T_1f18a_row13_col0, #T_1f18a_row24_col0 {
#   background-color: #95cbd2;
#   color: #000000;
# }
# #T_1f18a_row14_col0 {
#   background-color: #4798ce;
#   color: #f1f1f1;
# }
# #T_1f18a_row16_col0 {
#   background-color: #4265c5;
#   color: #f1f1f1;
# }
# #T_1f18a_row17_col0 {
#   background-color: #3b71cd;
#   color: #f1f1f1;
# }
# #T_1f18a_row18_col0 {
#   background-color: #3f90ce;
#   color: #f1f1f1;
# }
# #T_1f18a_row19_col0 {
#   background-color: #5da9cd;
#   color: #f1f1f1;
# }
# #T_1f18a_row20_col0 {
#   background-color: #72b6ce;
#   color: #000000;
# }
# #T_1f18a_row21_col0 {
#   background-color: #84c1cf;
#   color: #000000;
# }
# #T_1f18a_row22_col0 {
#   background-color: #9ed1d3;
#   color: #000000;
# }
# #T_1f18a_row23_col0 {
#   background-color: #a9d9d6;
#   color: #000000;
# }
# #T_1f18a_row25_col0 {
#   background-color: #78b9ce;
#   color: #000000;
# }
# #T_1f18a_row26_col0 {
#   background-color: #4596ce;
#   color: #f1f1f1;
# }
# #T_1f18a_row28_col0 {
#   background-color: #3a73ce;
#   color: #f1f1f1;
# }
# #T_1f18a_row29_col0 {
#   background-color: #42407b;
#   color: #f1f1f1;
# }
# #T_1f18a_row30_col0 {
#   background-color: #333153;
#   color: #f1f1f1;
# }
# #T_1f18a_row31_col0 {
#   background-color: #212028;
#   color: #f1f1f1;
# }
# #T_1f18a_row32_col0 {
#   background-color: #2f1f22;
#   color: #f1f1f1;
# }
# #T_1f18a_row33_col0 {
#   background-color: #5c2935;
#   color: #f1f1f1;
# }
# #T_1f18a_row34_col0, #T_1f18a_row35_col0 {
#   background-color: #d04537;
#   color: #f1f1f1;
# }
# #T_1f18a_row36_col0 {
#   background-color: #ffd4ac;
#   color: #000000;
# }
# </style>
# <table id="T_1f18a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1f18a_level0_col0" class="col_heading level0 col0" >OOFScore</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Grp</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1f18a_level0_row0" class="row_heading level0 row0" >100</th>
#       <td id="T_1f18a_row0_col0" class="data row0 col0" >167.0768</td>
#     </tr>
#     <tr>
#       <th id="T_1f18a_level0_row1" class="row_heading level0 row1" >130</th>
#       <td id="T_1f18a_row1_col0" class="data row1 col0" >148.0567</td>
#     </tr>
#     <tr>
#       <th id="T_1f18a_level0_row2" class="row_heading level0 row2" >150</th>
#       <td id="T_1f18a_row2_col0" class="data row2 col0" >125.7961</td>
#     </tr>
#     <tr>
#       <th id="T_1f18a_level0_row3" class="row_heading level0 row3" >180</th>
#       <td id="T_1f18a_row3_col0" class="data row3 col0" >74.4396</td>
#     </tr>
#     <tr>
#       <th id="T_1f18a_level0_row4" class="row_heading level0 row4" >200</th>
#       <td id="T_1f18a_row4_col0" class="data row4 col0" >88.4258</td>
#     </tr>
#     <tr>
#       <th id="T_1f18a_level0_row5" class="row_heading level0 row5" >229</th>
#       <td id="T_1f18a_row5_col0" class="data row5 col0" >63.4660</td>
#     </tr>
#     <tr>
#       <th id="T_1f18a_level0_row6" class="row_heading level0 row6" >250</th>
#       <td id="T_1f18a_row6_col0" class="data row6 col0" >53.9365</td>
#     </tr>
#     <tr>
#       <th id="T_1f18a_level0_row7" class="row_heading level0 row7" >280</th>
#       <td id="T_1f18a_row7_col0" class="data row7 col0" >82.0393</td>
#     </tr>
#     <tr>
#       <th id="T_1f18a_level0_row8" class="row_heading level0 row8" >290</th>
#       <td id="T_1f18a_row8_col0" class="data row8 col0" >93.1013</td>
#     </tr>
#     <tr>
#       <th id="T_1f18a_level0_row9" class="row_heading level0 row9" >300</th>
#       <td id="T_1f18a_row9_col0" class="data row9 col0" >63.0715</td>
#     </tr>
#     <tr>
#       <th id="T_1f18a_level0_row10" class="row_heading level0 row10" >320</th>
#       <td id="T_1f18a_row10_col0" class="data row10 col0" >7.4417</td>
#     </tr>
#     <tr>
#       <th id="T_1f18a_level0_row11" class="row_heading level0 row11" >330</th>
#       <td id="T_1f18a_row11_col0" class="data row11 col0" >74.8717</td>
#     </tr>
#     <tr>
#       <th id="T_1f18a_level0_row12" class="row_heading level0 row12" >350</th>
#       <td id="T_1f18a_row12_col0" class="data row12 col0" >84.4126</td>
#     </tr>
#     <tr>
#       <th id="T_1f18a_level0_row13" class="row_heading level0 row13" >360</th>
#       <td id="T_1f18a_row13_col0" class="data row13 col0" >29.4476</td>
#     </tr>
#     <tr>
#       <th id="T_1f18a_level0_row14" class="row_heading level0 row14" >380</th>
#       <td id="T_1f18a_row14_col0" class="data row14 col0" >70.7379</td>
#     </tr>
#     <tr>
#       <th id="T_1f18a_level0_row15" class="row_heading level0 row15" >400</th>
#       <td id="T_1f18a_row15_col0" class="data row15 col0" >73.7075</td>
#     </tr>
#     <tr>
#       <th id="T_1f18a_level0_row16" class="row_heading level0 row16" >430</th>
#       <td id="T_1f18a_row16_col0" class="data row16 col0" >105.9220</td>
#     </tr>
#     <tr>
#       <th id="T_1f18a_level0_row17" class="row_heading level0 row17" >450</th>
#       <td id="T_1f18a_row17_col0" class="data row17 col0" >98.3137</td>
#     </tr>
#     <tr>
#       <th id="T_1f18a_level0_row18" class="row_heading level0 row18" >480</th>
#       <td id="T_1f18a_row18_col0" class="data row18 col0" >77.6476</td>
#     </tr>
#     <tr>
#       <th id="T_1f18a_level0_row19" class="row_heading level0 row19" >500</th>
#       <td id="T_1f18a_row19_col0" class="data row19 col0" >56.9992</td>
#     </tr>
#     <tr>
#       <th id="T_1f18a_level0_row20" class="row_heading level0 row20" >530</th>
#       <td id="T_1f18a_row20_col0" class="data row20 col0" >46.5347</td>
#     </tr>
#     <tr>
#       <th id="T_1f18a_level0_row21" class="row_heading level0 row21" >550</th>
#       <td id="T_1f18a_row21_col0" class="data row21 col0" >37.8317</td>
#     </tr>
#     <tr>
#       <th id="T_1f18a_level0_row22" class="row_heading level0 row22" >580</th>
#       <td id="T_1f18a_row22_col0" class="data row22 col0" >24.2115</td>
#     </tr>
#     <tr>
#       <th id="T_1f18a_level0_row23" class="row_heading level0 row23" >600</th>
#       <td id="T_1f18a_row23_col0" class="data row23 col0" >19.3239</td>
#     </tr>
#     <tr>
#       <th id="T_1f18a_level0_row24" class="row_heading level0 row24" >620</th>
#       <td id="T_1f18a_row24_col0" class="data row24 col0" >28.6987</td>
#     </tr>
#     <tr>
#       <th id="T_1f18a_level0_row25" class="row_heading level0 row25" >630</th>
#       <td id="T_1f18a_row25_col0" class="data row25 col0" >44.6471</td>
#     </tr>
#     <tr>
#       <th id="T_1f18a_level0_row26" class="row_heading level0 row26" >650</th>
#       <td id="T_1f18a_row26_col0" class="data row26 col0" >72.9874</td>
#     </tr>
#     <tr>
#       <th id="T_1f18a_level0_row27" class="row_heading level0 row27" >680</th>
#       <td id="T_1f18a_row27_col0" class="data row27 col0" >92.8025</td>
#     </tr>
#     <tr>
#       <th id="T_1f18a_level0_row28" class="row_heading level0 row28" >700</th>
#       <td id="T_1f18a_row28_col0" class="data row28 col0" >96.1848</td>
#     </tr>
#     <tr>
#       <th id="T_1f18a_level0_row29" class="row_heading level0 row29" >730</th>
#       <td id="T_1f18a_row29_col0" class="data row29 col0" >137.9145</td>
#     </tr>
#     <tr>
#       <th id="T_1f18a_level0_row30" class="row_heading level0 row30" >750</th>
#       <td id="T_1f18a_row30_col0" class="data row30 col0" >155.7409</td>
#     </tr>
#     <tr>
#       <th id="T_1f18a_level0_row31" class="row_headi
# CPU times: user 3.59 s, sys: 2.6 s, total: 6.19 s
# Wall time: 6.19 s

# %%
# %%time 

if CFG.ensemble_req == "Y":
    sub_fl[['id', CFG.target]].to_csv(f"SubNoPP_V{CFG.version_nb}.csv", index = None);
    
    PrintColor(f"\n---> Blending with good public work\n");
    sub_fl['nb1'] = \
    pd.read_csv(f"/kaggle/input/pss3e25-autogluon/median_absolute_error.csv")[CFG.target].values;
    sub_fl['nb2'] = \
    pd.read_csv(f"/kaggle/input/ps3e25-mohs-hardness-ensembling-method/submission.csv")[CFG.target].values;   
    
    sub_fl[CFG.target] = sub_fl[CFG.target] * 0.15 + sub_fl['nb1'] * 0.60 + sub_fl['nb1'] * 0.25;
    
    # Post-processing the final predictions with the duplicate row predictions:-
    _ = \
    sub_fl[['id', CFG.target]].\
    merge(dups_df[['id_test', CFG.target]], 
          how = "left", left_on = 'id', right_on = "id_test", suffixes = ("_test", "_train")).\
    fillna(-1);
    _[CFG.target] = np.where(_[f"{CFG.target}_train"] == -1,
                             _[f"{CFG.target}_test"], 
                             _[f"{CFG.target}_train"]/ CFG.tgt_scl_fct
                            );
    
    _[CFG.target] = PostProcessPred(_[CFG.target], "Y", 1);
    
    PrintColor(f"\n---> Submission file- final check after post-processing\n");
    display(_[CFG.target].describe());
    _[['id', CFG.target]].to_csv(f"Submission_V{CFG.version_nb}.csv", index = None);
    
    PrintColor(f"\n---> Submission file after post-processing\n");
    display(_[['id', CFG.target]].head(10).style.format(precision = 3));
    del _;
    
if CFG.ML == "Y":  
    OOF_Preds.add_prefix(f"V{CFG.version_nb}_").to_csv(f"OOF_Preds_V{CFG.version_nb}.csv");
    Mdl_Preds.add_prefix(f"V{CFG.version_nb}_").to_csv(f"Mdl_Preds_V{CFG.version_nb}.csv"); 
    if isinstance(Scores, pd.DataFrame) == True:
        Scores.to_csv(f"Scores_V{CFG.version_nb}.csv");
          
collect();
print();
# Out:
# ---> Blending with good public work
#
#
# ---> Submission file- final check after post-processing
# count    6939.000000
# mean        4.725214
# std         1.349296
# min         1.450781
# 25%         3.454343
# 50%         5.435926
# 75%         5.867471
# max         9.751358
# Name: Hardness, dtype: float64
# ---> Submission file after post-processing
# <style type="text/css">
# </style>
# <table id="T_ca8d6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ca8d6_level0_col0" class="col_heading level0 col0" >id</th>
#       <th id="T_ca8d6_level0_col1" class="col_heading level0 col1" >Hardness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ca8d6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ca8d6_row0_col0" class="data row0 col0" >10407</td>
#       <td id="T_ca8d6_row0_col1" class="data row0 col1" >2.649</td>
#     </tr>
#     <tr>
#       <th id="T_ca8d6_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ca8d6_row1_col0" class="data row1 col0" >10408</td>
#       <td id="T_ca8d6_row1_col1" class="data row1 col1" >2.533</td>
#     </tr>
#     <tr>
#       <th id="T_ca8d6_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_ca8d6_row2_col0" class="data row2 col0" >10409</td>
#       <td id="T_ca8d6_row2_col1" class="data row2 col1" >5.904</td>
#     </tr>
#     <tr>
#       <th id="T_ca8d6_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_ca8d6_row3_col0" class="data row3 col0" >10410</td>
#       <td id="T_ca8d6_row3_col1" class="data row3 col1" >4.766</td>
#     </tr>
#     <tr>
#       <th id="T_ca8d6_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_ca8d6_row4_col0" class="data row4 col0" >10411</td>
#       <td id="T_ca8d6_row4_col1" class="data row4 col1" >5.356</td>
#     </tr>
#     <tr>
#       <th id="T_ca8d6_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_ca8d6_row5_col0" class="data row5 col0" >10412</td>
#       <td id="T_ca8d6_row5_col1" class="data row5 col1" >5.548</td>
#     </tr>
#     <tr>
#       <th id="T_ca8d6_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_ca8d6_row6_col0" class="data row6 col0" >10413</td>
#       <td id="T_ca8d6_row6_col1" class="data row6 col1" >3.640</td>
#     </tr>
#     <tr>
#       <th id="T_ca8d6_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_ca8d6_row7_col0" class="data row7 col0" >10414</td>
#       <td id="T_ca8d6_row7_col1" class="data row7 col1" >5.532</td>
#     </tr>
#     <tr>
#       <th id="T_ca8d6_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_ca8d6_row8_col0" class="data row8 col0" >10415</td>
#       <td id="T_ca8d6_row8_col1" class="data row8 col1" >2.873</td>
#     </tr>
#     <tr>
#       <th id="T_ca8d6_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_ca8d6_row9_col0" class="data row9 col0" >10416</td>
#       <td id="T_ca8d6_row9_col1" class="data row9 col1" >5.024</td>
#     </tr>
#   </tbody>
# </table>
# CPU times: user 575 ms, sys: 19 ms, total: 594 ms
# Wall time: 620 ms

# %% [markdown]
# <a id="9"></a>
# # <div style= "font-family: Cambria; font-weight:bold; letter-spacing: 0px; color:#ffffff; font-size:120%; text-align:left;padding:3.0px; background: #0052cc; border-bottom: 8px solid #cc9966" > NEXT STEPS<br> <div>

# %% [markdown]
# <div style= "font-family: Cambria; letter-spacing: 0px; color:#000000; font-size:110%; text-align:left;padding:3.0px; background: #f2f2f2" >
# 1. We will perform a detailed EDA and elicit feature interactions and other relevant insights<br>
# 2. Model tuning<br>
# 3. Including other models in the ensemble <br>
# 4. Better ensemble strategy <br>
# 5. Any other discussion/ public work based insights <br>
# 6. Significant improvement on edge predictions <br>
# </div>

# %% [markdown]
# # <div style= "font-family: Cambria; font-weight:bold; letter-spacing: 0px; color:blue; font-size:90%; text-align:left;padding:3.0px; background: #lightgrey" > If you find my work useful, please upvote and share the notebook.<br> Best regards!!<br> <div>
